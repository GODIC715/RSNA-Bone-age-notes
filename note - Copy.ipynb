# %%
import re, math
import numpy as np
from functools import partial
from sklearn.model_selection import train_test_split
# from kaggle_datasets import KaggleDatasets
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, Flatten, AveragePooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Number of replicas: 1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [512, 512]
# GCS_PATH = KaggleDatasets().get_gcs_path()
HEIGHT = 512
WIDTH = 512
CHANNELS = 1

# %%
def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.rgb_to_grayscale(image)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, IMAGE_SIZE)
    return image

# %%
def read_tfrecord(example):
    tfrecord_format = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'image_id': tf.io.FixedLenFeature([], tf.string),
        'boneage': tf.io.FixedLenFeature([], tf.int64),
        'male': tf.io.FixedLenFeature([], tf.int64)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    boneAge = tf.cast(example['boneage'], tf.int32)
    male = tf.cast(example['male'], tf.bool)
    inputs = {}
    inputs['image'] = image
    inputs['gender'] = male
    return inputs, boneAge

# %%
def load_dataset(filenames):
    ignore_order = tf.data.Options()
    ignore_order.experimental_deterministic = False # disable order, increase speed
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(partial(read_tfrecord), num_parallel_calls=AUTOTUNE)
    return dataset

# %%
TRAINING_FILENAMES, VALID_FILENAMES = train_test_split(
    # tf.io.gfile.glob(GCS_PATH + '/bone_age_tfrecords/*.tfrec'),
    tf.io.gfile.glob('../bone-age-tfrecords/*.tfrec'),
    test_size=0.2, random_state=2018
)

# %%
def custom_data_augment(inputs, boneAge):
    image = inputs['image']
    p_rotation = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    # p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    # Shear
    if p_shear > .2:
        if p_shear > .6:
            image = transform_shear(image, HEIGHT, shear=20.)
        else:
            image = transform_shear(image, HEIGHT, shear=-20.)
            
    # Rotation
    if p_rotation > .2:
        if p_rotation > .6:
            image = transform_rotation(image, HEIGHT, rotation=45.)
        else:
            image = transform_rotation(image, HEIGHT, rotation=-45.)
            
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k=2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k=1) # rotate 90º
        
    # Pixel-level transforms
    # if p_pixel_1 >= .4:
    #     image = tf.image.random_saturation(image, lower=.7, upper=1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower=.8, upper=1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta=.1)
        
    # Crops
    if p_crop > .7:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .4:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])
            
    image = tf.image.resize(image, size=[HEIGHT, WIDTH])

    inputs['image'] = image
    return inputs, boneAge

# %%
# data augmentation @cdeotte kernel: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
def transform_rotation(image, height, rotation):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    rotation = rotation * tf.random.uniform([1],dtype='float32')
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    rotation_matrix = tf.reshape(tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0),[3,3])

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(rotation_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,1])

def transform_shear(image, height, shear):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly sheared
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    shear = shear * tf.random.uniform([1],dtype='float32')
    shear = math.pi * shear / 180.
        
    # SHEAR MATRIX
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape(tf.concat([one,s2,zero, zero,c2,zero, zero,zero,one],axis=0),[3,3])    

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(shear_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,1])

# %%
def get_training_dataset():
    dataset = load_dataset(TRAINING_FILENAMES)  
    dataset = dataset.map(custom_data_augment, num_parallel_calls=AUTOTUNE)  
    dataset = dataset.repeat()
    dataset = dataset.shuffle(1024)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

# %%
def get_validation_dataset():
    dataset = load_dataset(VALID_FILENAMES) 
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

# %%
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

# %%
NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALID_FILENAMES)

print('Dataset: {} training images, {} validation images'.format(
    NUM_TRAINING_IMAGES, NUM_VALIDATION_IMAGES))
# Out:
# Dataset: 10088 training images, 2523 validation images

# %%
bestLr = 0.0107977516232771
weight_path = "{}_weights.best.hdf5".format('bone_age')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                            save_best_only=True, mode='min', save_weights_only=True)

early = EarlyStopping(monitor="val_loss", mode="min",
                      patience=20)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, verbose=1,
                                   save_best_only=True, mode='auto', min_delta=0.0001, cooldown=5)
optimizer = Adam(learning_rate = bestLr, beta_1 = 0.9, beta_2 = 0.999, epsilon = 0.1)
callBacks = [early, reduceLROnPlat, checkpoint]

# %%
with strategy.scope():       
    i1 = Input(shape=(512, 512, 1), name='image')
    i2 = Input(shape=(1), name='gender')
    base = InceptionV3(input_tensor=i1, input_shape=(512, 512, 1), include_top=False, weights=None)

    feature_img = base.get_layer(name='mixed10').output
    feature_img = AveragePooling2D((2, 2))(feature_img)
    feature_img = Flatten()(feature_img)
    feature_gender = Dense(32, activation='relu')(i2)
    feature = concatenate([feature_img, feature_gender], axis=1)

    o = Dense(1000, activation='relu')(feature)
    o = Dense(1000, activation='relu')(o)
    o = Dense(1)(o)
    model = Model(inputs=[i1, i2], outputs=o)
    model.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mae'])

# %%
train_dataset = get_training_dataset()
valid_dataset = get_validation_dataset()

# %%
STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE
VALID_STEPS = NUM_VALIDATION_IMAGES // BATCH_SIZE

# %%
initalHistory = model.fit(train_dataset, 
                    steps_per_epoch=STEPS_PER_EPOCH, 
                    epochs=250,
                    validation_data=valid_dataset,
                    validation_steps=VALID_STEPS,
                    callbacks = callBacks)
# Out:
# Epoch 1/250
# 630/630 [==============================] - ETA: 0s - loss: 38.9419 - mae: 38.9419
# Epoch 00001: val_loss improved from inf to 37.50946, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 347s 504ms/step - loss: 38.9419 - mae: 38.9419 - val_loss: 37.5095 - val_mae: 37.5095 - lr: 0.0108
# Epoch 2/250
# 630/630 [==============================] - ETA: 0s - loss: 34.6132 - mae: 34.6132
# Epoch 00002: val_loss improved from 37.50946 to 36.45212, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] -
# 630/630 [==============================] - 285s 452ms/step - loss: 29.5367 - mae: 29.5367 - val_loss: 36.5868 - val_mae: 36.5868 - lr: 0.0044
# Epoch 45/250
# 630/630 [==============================] - ETA: 0s - loss: 28.7352 - mae: 28.7352
# Epoch 00045: val_loss did not improve from 28.05522
# 630/630 [==============================] - 281s 446ms/step - loss: 28.7352 - mae: 28.7352 - val_loss: 32.2716 - val_mae: 32.2716 - lr: 0.0044
# Epoch 46/250
# 630/630 [==============================] - ETA: 0s - loss: 28.1564 - mae: 28.1564
# Epoch 00046: val_loss did not improve from 28.05522
# 630/630 [==============================] - 273s 433ms/step - loss: 28.1564 - mae: 28.1564 - val_loss: 37.9635 - val_mae: 37.9635 - lr: 0.0044
# Epoch 47/250
# 630/630 [==============================] - ETA: 0s - loss: 27.7551 - mae: 27.7551
# Epoch 00047: val_loss did not improve from 28.05522
# 630/630 [==============================] - 282s 447ms/step - loss: 27.7551 - mae: 27.7551 - val_loss: 30.4672 - val_mae: 30.4672 - lr: 0.0044
# Epoch 48/250
# 630/630 [==============================] - ETA: 0s - loss: 27.1946 - mae: 27.1946
# Epoch 00048: val_loss did not improve from 28.05522
# 630/630 [==============================] - 286s 453ms/step - loss: 27.1946 - mae: 27.1946 - val_loss: 100.4782 - val_mae: 100.4782 - lr: 0.0044
# Epoch 49/250
# 630/630 [==============================] - ETA: 0s - loss: 26.7504 - mae: 26.7504
# Epoch 00049: val_loss did not improve from 28.05522
# 630/630 [==============================] - 286s 454ms/step - loss: 26.7504 - mae: 26.7504 - val_loss: 32.0304 - val_mae: 32.0304 - lr: 0.0044
# Epoch 50/250
# 630/630 [==============================] - ETA: 0s - loss: 26.7421 - mae: 26.7421
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0035382073372602465.
#
# Epoch 00050: val_loss did not improve from 28.05522
# 630/630 [==============================] - 291s 461ms/step - loss: 26.7421 - mae: 26.7421 - val_loss: 31.3142 - val_mae: 31.3142 - lr: 0.0044
# Epoch 51/250
# 630/630 [==============================] - ETA: 0s - loss: 25.7898 - mae: 25.7898
# Epoch 00051: val_loss did not improve from 28.05522
# 630/630 [==============================] - 298s 473ms/step - loss: 25.7898 - mae: 25.7898 - val_loss: 28.9424 - val_mae: 28.9424 - lr: 0.0035
# Epoch 52/250
# 630/630 [==============================] - ETA: 0s - loss: 25.6897 - mae: 25.6897
# Epoch 00052: val_loss improved from 28.05522 to 25.45415, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 295s 469ms/step - loss: 25.6897 - mae: 25.6897 - val_loss: 25.4541 - val_mae: 25.4541 - lr: 0.0035
# Epoch 53/250
# 630/630 [==============================] - ETA: 0s - loss: 25.1865 - mae: 25.1865
# Epoch 00053: val_loss did not improve from 25.45415
# 630/630 [==============================] - 289s 458ms/step - loss: 25.1865 - mae: 25.1865 - val_loss: 37.4574 - val_mae: 37.4574 - lr: 0.0035
# Epoch 54/250
# 630/630 [==============================] - ETA: 0s - loss: 24.7555 - mae: 24.7555
# Epoch 00054: val_loss improved from 25.45415 to 19.70121, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] -
# 630/630 [==============================] - 275s 437ms/step - loss: 20.6086 - mae: 20.6086 - val_loss: 24.2288 - val_mae: 24.2288 - lr: 0.0028
# Epoch 66/250
# 630/630 [==============================] - ETA: 0s - loss: 19.9512 - mae: 19.9512
# Epoch 00066: val_loss did not improve from 16.57468
# 630/630 [==============================] - 275s 437ms/step - loss: 19.9512 - mae: 19.9512 - val_loss: 17.1400 - val_mae: 17.1400 - lr: 0.0028
# Epoch 67/250
# 630/630 [==============================] - ETA: 0s - loss: 19.5500 - mae: 19.5500
# Epoch 00067: val_loss improved from 16.57468 to 16.21487, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 290s 460ms/step - loss: 19.5500 - mae: 19.5500 - val_loss: 16.2149 - val_mae: 16.2149 - lr: 0.0028
# Epoch 68/250
# 630/630 [==============================] - ETA: 0s - loss: 19.6372 - mae: 19.6372
# Epoch 00068: val_loss did not improve from 16.21487
# 630/630 [==============================] - 290s 461ms/step - loss: 19.6372 - mae: 19.6372 - val_loss: 19.4868 - val_mae: 19.4868 - lr: 0.0028
# Epoch 69/250
# 630/630 [==============================] - ETA: 0s - loss: 18.8731 - mae: 18.8731
# Epoch 00069: val_loss did not improve from 16.21487
# 630/630 [==============================] - 290s 460ms/step - loss: 18.8731 - mae: 18.8731 - val_loss: 37.9940 - val_mae: 37.9940 - lr: 0.0028
# Epoch 70/250
# 630/630 [==============================] - ETA: 0s - loss: 18.9228 - mae: 18.9228
# Epoch 00070: val_loss improved from 16.21487 to 13.01693, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 295s 469ms/step - loss: 18.9228 - mae: 18.9228 - val_loss: 13.0169 - val_mae: 13.0169 - lr: 0.0028
# Epoch 71/250
# 630/630 [==============================] - ETA: 0s - loss: 18.3126 - mae: 18.3126
# Epoch 00071: val_loss did not improve from 13.01693
# 630/630 [==============================] - 287s 456ms/step - loss: 18.3126 - mae: 18.3126 - val_loss: 20.5967 - val_mae: 20.5967 - lr: 0.0028
# Epoch 72/250
# 630/630 [==============================] - ETA: 0s - loss: 17.7925 - mae: 17.7925
# Epoch 00072: val_loss improved from 13.01693 to 11.20396, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 294s 467ms/step - loss: 17.7925 - mae: 17.7925 - val_loss: 11.2040 - val_mae: 11.2040 - lr: 0.0028
# Epoch 73/250
# 630/630 [==============================] - ETA: 0s - loss: 17.4129 - mae: 17.4129
# Epoch 00073: val_loss did not improve from 11.20396
# 630/630 [==============================] - 279s 443ms/step - loss: 17.4129 - mae: 17.4129 - val_loss: 13.4562 - val_mae: 13.4562 - lr: 0.0028
# Epoch 74/250
# 630/630 [==============================] - ETA: 0s - loss: 17.0805 - mae: 17.0805
# Epoch 00074: val_loss did not improve from 11.20396
# 630/630 [==============================] - 277s 440ms/step - loss: 17.0805 - mae: 17.0805 - val_loss: 14.1005 - val_mae: 14.1005 - lr: 0.0028
# Epoch 75/250
# 630/630 [==============================] - ETA: 0s - loss: 16.8726 - mae: 16.8726
# Epoch 00075: val_loss did not improve from 11.20396
# 630/630 [==============================] - 279s 444ms/step - loss: 16.8726 - mae: 16.8726 - val_loss: 15.1880 - val_mae: 15.1880 - lr: 0.0028
# Epoch 76/250
# 630/630 [==============================] - ETA: 0s - loss: 16.2296 - mae: 16.2296
# Epoch 00076: val_loss did not improve from 11.20396
# 630/630 [==============================] - 277s 440ms/step - loss: 16.2296 - mae: 16.2296 - val_loss: 18.3724 - val_mae: 18.3724 - lr: 0.0028
# Epoch 77/250
# 630/630 [==============================] - ETA: 0s - loss: 16.0488 - mae: 16.0488
# Epoch 00077: ReduceLROnPlateau reducing learning rate to
# 630/630 [==============================] - ETA: 0s - loss: 10.1418 - mae: 10.1418
# Epoch 00097: val_loss did not improve from 8.51482
# 630/630 [==============================] - 285s 453ms/step - loss: 10.1418 - mae: 10.1418 - val_loss: 11.5203 - val_mae: 11.5203 - lr: 0.0018
# Epoch 98/250
# 630/630 [==============================] - ETA: 0s - loss: 10.6352 - mae: 10.6352
# Epoch 00098: val_loss improved from 8.51482 to 8.35632, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 295s 468ms/step - loss: 10.6352 - mae: 10.6352 - val_loss: 8.3563 - val_mae: 8.3563 - lr: 0.0018
# Epoch 99/250
# 630/630 [==============================] - ETA: 0s - loss: 10.0820 - mae: 10.0820
# Epoch 00099: val_loss did not improve from 8.35632
# 630/630 [==============================] - 296s 469ms/step - loss: 10.0820 - mae: 10.0820 - val_loss: 15.1221 - val_mae: 15.1221 - lr: 0.0018
# Epoch 100/250
# 630/630 [==============================] - ETA: 0s - loss: 10.1106 - mae: 10.1106
# Epoch 00100: val_loss did not improve from 8.35632
# 630/630 [==============================] - 293s 464ms/step - loss: 10.1106 - mae: 10.1106 - val_loss: 9.6265 - val_mae: 9.6265 - lr: 0.0018
# Epoch 101/250
# 630/630 [==============================] - ETA: 0s - loss: 10.0644 - mae: 10.0644
# Epoch 00101: val_loss did not improve from 8.35632
# 630/630 [==============================] - 286s 453ms/step - loss: 10.0644 - mae: 10.0644 - val_loss: 12.1364 - val_mae: 12.1364 - lr: 0.0018
# Epoch 102/250
# 630/630 [==============================] - ETA: 0s - loss: 9.9256 - mae: 9.9256
# Epoch 00102: val_loss improved from 8.35632 to 8.25313, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 290s 460ms/step - loss: 9.9256 - mae: 9.9256 - val_loss: 8.2531 - val_mae: 8.2531 - lr: 0.0018
# Epoch 103/250
# 630/630 [==============================] - ETA: 0s - loss: 9.9512 - mae: 9.9512
# Epoch 00103: val_loss did not improve from 8.25313
# 630/630 [==============================] - 288s 457ms/step - loss: 9.9512 - mae: 9.9512 - val_loss: 8.4695 - val_mae: 8.4695 - lr: 0.0018
# Epoch 104/250
# 630/630 [==============================] - ETA: 0s - loss: 10.0257 - mae: 10.0257
# Epoch 00104: val_loss did not improve from 8.25313
# 630/630 [==============================] - 300s 476ms/step - loss: 10.0257 - mae: 10.0257 - val_loss: 9.2234 - val_mae: 9.2234 - lr: 0.0018
# Epoch 105/250
# 630/630 [==============================] - ETA: 0s - loss: 9.7768 - mae: 9.7768
# Epoch 00105: val_loss improved from 8.25313 to 8.15675, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 308s 489ms/step - loss: 9.7768 - mae: 9.7768 - val_loss: 8.1568 - val_mae: 8.1568 - lr: 0.0018
# Epoch 106/250
# 630/630 [==============================] - ETA: 0s - loss: 9.6838 - mae: 9.6838
# Epoch 00106: val_loss did not improve from 8.15675
# 630/630 [==============================] - 301s 477ms/step - loss: 9.6838 - mae: 9.6838 - val_loss: 8.5352 - val_mae: 8.5352 - lr: 0.0018
# Epoch 107/250
# 630/630 [==============================] - ETA: 0s - loss: 9.8020 - mae: 9.8020
# Epoch 00107: val_loss did not improve from 8.15675
# Epoch 118/250
# 630/630 [==============================] - ETA: 0s - loss: 8.9799 - mae: 8.9799
# Epoch 00118: val_loss did not improve from 7.79491
# 630/630 [==============================] - 280s 444ms/step - loss: 8.9799 - mae: 8.9799 - val_loss: 7.8977 - val_mae: 7.8977 - lr: 0.0014
# Epoch 119/250
# 630/630 [==============================] - ETA: 0s - loss: 9.0187 - mae: 9.0187
# Epoch 00119: val_loss improved from 7.79491 to 7.66384, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 288s 457ms/step - loss: 9.0187 - mae: 9.0187 - val_loss: 7.6638 - val_mae: 7.6638 - lr: 0.0014
# Epoch 120/250
# 630/630 [==============================] - ETA: 0s - loss: 9.0779 - mae: 9.0779
# Epoch 00120: val_loss did not improve from 7.66384
# 630/630 [==============================] - 289s 459ms/step - loss: 9.0779 - mae: 9.0779 - val_loss: 9.1204 - val_mae: 9.1204 - lr: 0.0014
# Epoch 121/250
# 630/630 [==============================] - ETA: 0s - loss: 8.9694 - mae: 8.9694
# Epoch 00121: val_loss improved from 7.66384 to 7.55302, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 303s 482ms/step - loss: 8.9694 - mae: 8.9694 - val_loss: 7.5530 - val_mae: 7.5530 - lr: 0.0014
# Epoch 122/250
# 630/630 [==============================] - ETA: 0s - loss: 8.7715 - mae: 8.7715
# Epoch 00122: val_loss did not improve from 7.55302
# 630/630 [==============================] - 294s 467ms/step - loss: 8.7715 - mae: 8.7715 - val_loss: 7.7221 - val_mae: 7.7221 - lr: 0.0014
# Epoch 123/250
# 630/630 [==============================] - ETA: 0s - loss: 8.9111 - mae: 8.9111
# Epoch 00123: val_loss did not improve from 7.55302
# 630/630 [==============================] - 295s 469ms/step - loss: 8.9111 - mae: 8.9111 - val_loss: 7.9085 - val_mae: 7.9085 - lr: 0.0014
# Epoch 124/250
# 630/630 [==============================] - ETA: 0s - loss: 8.9148 - mae: 8.9148
# Epoch 00124: val_loss did not improve from 7.55302
# 630/630 [==============================] - 293s 465ms/step - loss: 8.9148 - mae: 8.9148 - val_loss: 8.0262 - val_mae: 8.0262 - lr: 0.0014
# Epoch 125/250
# 630/630 [==============================] - ETA: 0s - loss: 8.9810 - mae: 8.9810
# Epoch 00125: val_loss did not improve from 7.55302
# 630/630 [==============================] - 291s 462ms/step - loss: 8.9810 - mae: 8.9810 - val_loss: 7.8363 - val_mae: 7.8363 - lr: 0.0014
# Epoch 126/250
# 630/630 [==============================] - ETA: 0s - loss: 8.8389 - mae: 8.8389
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 0.0011593997478485107.
#
# Epoch 00126: val_loss did not improve from 7.55302
# 630/630 [==============================] - 290s 461ms/step - loss: 8.8389 - mae: 8.8389 - val_loss: 7.8406 - val_mae: 7.8406 - lr: 0.0014
# Epoch 127/250
# 630/630 [==============================] - ETA: 0s - loss: 8.7338 - mae: 8.7338
# Epoch 00127: val_loss did not improve from 7.55302
# 630/630 [==============================] - 292s 463ms/step - loss: 8.7338 - mae: 8.7338 - val_loss: 7.5914 - val_mae: 7.5914 - lr: 0.0012
# Epoch 128/250
# 630/630 [==============================] - ETA: 0s - loss: 8.5641 - mae: 8.5641
# Epoch 00128: val_loss did not improve from 7.55302
# 630/630 [==============================] - 295s 468ms/step - loss: 8.5641 - mae: 8.5641 - val_loss: 7.9201 - val_mae: 7.9201 - lr: 0.0012
# Epoch 129/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4608 - mae: 8.4608
# Epoch 00129: val_loss did not improve from 7.55302
# 630/630 [==============================] - 291s 462ms/step - loss: 8.4608 - mae: 8.4608 - val_loss: 8.1653 - val_mae: 8.1653 - lr: 0.0012
# Epoch 130/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4762 - mae: 8.4762
# Epoch 00130: val_loss improved from 7.55302 to 7.27379, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 296s 470ms/step - loss: 8.4762 - mae: 8.4762 - val_loss: 7.2738 - val_mae: 7.2738 - lr: 0.0012
# Epoch 131/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4506 - mae: 8.4506
# Epoch 00131: val_loss did not improve from 7.27379
# 630/630 [==============================] - 301s 477ms/step - loss: 8.4506 - mae: 8.4506 - val_loss: 9.2702 - val_mae: 9.2702 - lr: 0.0012
# Epoch 132/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4514 - mae: 8.4514
# Epoch 00132: val_loss improved from 7.27379 to 7.18593, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 296s 470ms/step - loss: 8.4514 - mae: 8.4514 - val_loss: 7.1859 - val_mae: 7.1859 - lr: 0.0012
# Epoch 133/250
# 630/630 [==============================] - ETA: 0s - loss: 8.5066 - mae: 8.5066
# Epoch 00133: val_loss did not improve from 7.18593
# 630/630 [==============================] - 286s 454ms/step - loss: 8.5066 - mae: 8.5066 - val_loss: 7.8573 - val_mae: 7.8573 - lr: 0.0012
# Epoch 134/250
# 630/630 [==============================] - ETA: 0s - loss: 8.3944 - mae: 8.3944
# Epoch 00134: val_loss improved from 7.18593 to 7.13639, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 303s 480ms/step - loss: 8.3944 - mae: 8.3944 - val_loss: 7.1364 - val_mae: 7.1364 - lr: 0.0012
# Epoch 135/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4091 - mae: 8.4091
# Epoch 00135: val_loss did not improve from 7.13639
# 630/630 [==============================] - 297s 470ms/step - loss: 8.4091 - mae: 8.4091 - val_loss: 7.5158 - val_mae: 7.5158 - lr: 0.0012
# Epoch 136/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4495 - mae: 8.4495
# Epoch 00136: val_loss did not improve from 7.13639
# 630/630 [==============================] - 297s 471ms/step - loss: 8.4495 - mae: 8.4495 - val_loss: 8.4743 - val_mae: 8.4743 - lr: 0.0012
# Epoch 137/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4497 - mae: 8.4497
# Epoch 00137: val_loss did not improve from 7.13639
# 630/630 [==============================] - 297s 471ms/step - loss: 8.4497 - mae: 8.4497 - val_loss: 7.5410 - val_mae: 7.5410 - lr: 0.0012
# Epoch 138/250
# 630/630 [==============================] - ETA: 0s - loss: 8.4067 - mae: 8.4067
# Epoch 00138: val_loss did not improve from 7.13639
# 630/630 [==============================] - 296s 471ms/step - loss: 8.4067 - mae: 8.4067 - val_loss: 8.3391 - val_mae: 8.3391 - lr: 0.0012
# Epoch 139/250
# 630/630 [==============================] - ETA: 0s - loss: 8.3832 - mae: 8.3832
# Epoch 00139: ReduceLROnPlateau reducing learning rate to 0.0009275197982788086.
#
# Epoch 00139: val_loss did not improve from 7.13639
# 630/630 [==============================] - 287s 456ms/step - loss: 8.3832 - mae: 8.3832 - val_loss: 7.9311 - val_mae: 7.9311 - lr: 0.0012
# Epoch 140/250
# 630/630 [==============================] - ETA: 0s - loss: 8.2023 - mae: 8.2023
# Epoch 00140: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 433ms/step - loss: 8.2023 - mae: 8.2023 - val_loss: 7.1976 - val_mae: 7.1976 - lr: 9.2752e-04
# Epoch 141/250
# 630/630 [==============================] - ETA: 0s - loss: 8.1364 - mae: 8.1364
# Epoch 00141: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 433ms/step - loss: 8.1364 - mae: 8.1364 - val_loss: 7.4608 - val_mae: 7.4608 - lr: 9.2752e-04
# Epoch 142/250
# 630/630 [==============================] - ETA: 0s - loss: 8.2481 - mae: 8.2481
# Epoch 00142: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 434ms/step - loss: 8.2481 - mae: 8.2481 - val_loss: 7.4291 - val_mae: 7.4291 - lr: 9.2752e-04
# Epoch 143/250
# 630/630 [==============================] - ETA: 0s - loss: 8.1033 - mae: 8.1033
# Epoch 00143: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 433ms/step - loss: 8.1033 - mae: 8.1033 - val_loss: 8.1087 - val_mae: 8.1087 - lr: 9.2752e-04
# Epoch 144/250
# 630/630 [==============================] - ETA: 0s - loss: 8.2292 - mae: 8.2292
# Epoch 00144: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 433ms/step - loss: 8.2292 - mae: 8.2292 - val_loss: 7.1731 - val_mae: 7.1731 - lr: 9.2752e-04
# Epoch 145/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0949 - mae: 8.0949
# Epoch 00145: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 433ms/step - loss: 8.0949 - mae: 8.0949 - val_loss: 7.2396 - val_mae: 7.2396 - lr: 9.2752e-04
# Epoch 146/250
# 630/630 [==============================] - ETA: 0s - loss: 8.1490 - mae: 8.1490
# Epoch 00146: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 433ms/step - loss: 8.1490 - mae: 8.1490 - val_loss: 7.7418 - val_mae: 7.7418 - lr: 9.2752e-04
# Epoch 147/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0480 - mae: 8.0480
# Epoch 00147: val_loss did not improve from 7.13639
# 630/630 [==============================] - 273s 434ms/step - loss: 8.0480 - mae: 8.0480 - val_loss: 8.6584 - val_mae: 8.6584 - lr: 9.2752e-04
# Epoch 148/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0860 - mae: 8.0860
# Epoch 00148: val_loss improved from 7.13639 to 7.09356, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 280s 444ms/step - loss: 8.0860 - mae: 8.0860 - val_loss: 7.0936 - val_mae: 7.0936 - lr: 9.2752e-04
# Epoch 149/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0765 - mae: 8.0765
# Epoch 00149: val_loss did not improve from 7.09356
# 630/630 [==============================] - 273s 433ms/step - loss: 8.0765 - mae: 8.0765 - val_loss: 7.2068 - val_mae: 7.2068 - lr: 9.2752e-04
# Epoch 150/250
# 630/630 [==============================] - ETA: 0s - loss: 8.1666 - mae: 8.1666
# Epoch 00150: val_loss improved from 7.09356 to 7.06683, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 278s 442ms/step - loss: 8.1666 - mae: 8.1666 - val_loss: 7.0668 - val_mae: 7.0668 - lr: 9.2752e-04
# Epoch 151/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0637 - mae: 8.0637
# Epoch 00151: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 434ms/step - loss: 8.0637 - mae: 8.0637 - val_loss: 7.1279 - val_mae: 7.1279 - lr: 9.2752e-04
# Epoch 152/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0017 - mae: 8.0017
# Epoch 00152: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 433ms/step - loss: 8.0017 - mae: 8.0017 - val_loss: 7.4215 - val_mae: 7.4215 - lr: 9.2752e-04
# Epoch 153/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0395 - mae: 8.0395
# Epoch 00153: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 433ms/step - loss: 8.0395 - mae: 8.0395 - val_loss: 7.4181 - val_mae: 7.4181 - lr: 9.2752e-04
# Epoch 154/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0457 - mae: 8.0457
# Epoch 00154: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 433ms/step - loss: 8.0457 - mae: 8.0457 - val_loss: 7.8254 - val_mae: 7.8254 - lr: 9.2752e-04
# Epoch 155/250
# 630/630 [==============================] - ETA: 0s - loss: 8.0461 - mae: 8.0461
# Epoch 00155: ReduceLROnPlateau reducing learning rate to 0.0007420158479362727.
#
# Epoch 00155: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 433ms/step - loss: 8.0461 - mae: 8.0461 - val_loss: 7.1088 - val_mae: 7.1088 - lr: 9.2752e-04
# Epoch 156/250
# 630/630 [==============================] - ETA: 0s - loss: 7.9079 - mae: 7.9079
# Epoch 00156: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 433ms/step - loss: 7.9079 - mae: 7.9079 - val_loss: 7.2370 - val_mae: 7.2370 - lr: 7.4202e-04
# Epoch 157/250
# 630/630 [==============================] - ETA: 0s - loss: 7.9481 - mae: 7.9481
# Epoch 00157: val_loss did not improve from 7.06683
# 630/630 [==============================] - 272s 432ms/step - loss: 7.9481 - mae: 7.9481 - val_loss: 7.7380 - val_mae: 7.7380 - lr: 7.4202e-04
# Epoch 158/250
# 630/630 [==============================] - ETA: 0s - loss: 7.8229 - mae: 7.8229
# Epoch 00158: val_loss did not improve from 7.06683
# 630/630 [==============================] - 273s 433ms/step - loss: 7.8229 - mae: 7.8229 - val_loss: 7.0750 - val_mae: 7.0750 - lr: 7.4202e-04
250
# 630/630 [==============================] - ETA: 0s - loss: 7.4763 - mae: 7.4763
# Epoch 00181: val_loss did not improve from 6.67653
# 630/630 [==============================] - 272s 433ms/step - loss: 7.4763 - mae: 7.4763 - val_loss: 6.7033 - val_mae: 6.7033 - lr: 4.7489e-04
# Epoch 182/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4848 - mae: 7.4848
# Epoch 00182: val_loss improved from 6.67653 to 6.67413, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 281s 446ms/step - loss: 7.4848 - mae: 7.4848 - val_loss: 6.6741 - val_mae: 6.6741 - lr: 4.7489e-04
# Epoch 183/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4349 - mae: 7.4349
# Epoch 00183: val_loss did not improve from 6.67413
# 630/630 [==============================] - 273s 432ms/step - loss: 7.4349 - mae: 7.4349 - val_loss: 7.0321 - val_mae: 7.0321 - lr: 4.7489e-04
# Epoch 184/250
# 630/630 [==============================] - ETA: 0s - loss: 7.5274 - mae: 7.5274
# Epoch 00184: val_loss did not improve from 6.67413
# 630/630 [==============================] - 273s 433ms/step - loss: 7.5274 - mae: 7.5274 - val_loss: 7.1762 - val_mae: 7.1762 - lr: 4.7489e-04
# Epoch 185/250
# 630/630 [==============================] - ETA: 0s - loss: 7.5257 - mae: 7.5257
# Epoch 00185: val_loss did not improve from 6.67413
# 630/630 [==============================] - 272s 433ms/step - loss: 7.5257 - mae: 7.5257 - val_loss: 6.7749 - val_mae: 6.7749 - lr: 4.7489e-04
# Epoch 186/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4771 - mae: 7.4771
# Epoch 00186: val_loss did not improve from 6.67413
# 630/630 [==============================] - 272s 433ms/step - loss: 7.4771 - mae: 7.4771 - val_loss: 6.8277 - val_mae: 6.8277 - lr: 4.7489e-04
# Epoch 187/250
# 630/630 [==============================] - ETA: 0s - loss: 7.5153 - mae: 7.5153
# Epoch 00187: val_loss did not improve from 6.67413
# 630/630 [==============================] - 272s 432ms/step - loss: 7.5153 - mae: 7.5153 - val_loss: 7.5118 - val_mae: 7.5118 - lr: 4.7489e-04
# Epoch 188/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4890 - mae: 7.4890
# Epoch 00188: ReduceLROnPlateau reducing learning rate to 0.00037991211283952.
#
# Epoch 00188: val_loss did not improve from 6.67413
# 630/630 [==============================] - 272s 433ms/step - loss: 7.4890 - mae: 7.4890 - val_loss: 7.2820 - val_mae: 7.2820 - lr: 4.7489e-04
# Epoch 189/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4230 - mae: 7.4230
# Epoch 00189: val_loss did not improve from 6.67413
# 630/630 [==============================] - 272s 432ms/step - loss: 7.4230 - mae: 7.4230 - val_loss: 6.7696 - val_mae: 6.7696 - lr: 3.7991e-04
# Epoch 190/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4542 - mae: 7.4542
# Epoch 00190: val_loss did not improve from 6.67413
# 630/630 [==============================] - 272s 432ms/step - loss: 7.4542 - mae: 7.4542 - val_loss: 7.3506 - val_mae: 7.3506 - lr: 3.7991e-04
# Epoch 191/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4367 - mae: 7.4367
# Epoch 00191: val_loss did not improve from 6.67413
# 630/630 [==============================] - 273s 433ms/step - loss: 7.4367 - mae: 7.4367 - val_loss: 7.1812 - val_mae: 7.1812 - lr: 3.7991e-04
# Epoch 192/250
# 630/630 [==============================] - ETA: 0s - loss: 7.3604 - mae: 7.3604
# Epoch 00192: val_loss did not improve from 6.67413
# 630/630 [==============================] - 273s 433ms/step - loss: 7.3604 - mae: 7.3604 - val_loss: 7.2329 - val_mae: 7.2329 - lr: 3.7991e-04
# Epoch 193/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4193 - mae: 7.4193
# Epoch 00193: val_loss improved from 6.67413 to 6.65611, saving model to bone_age_weights.best.hdf5
# 630/630 [==============================] - 278s 441ms/step - loss: 7.4193 - mae: 7.4193 - val_loss: 6.6561 - val_mae: 6.6561 - lr: 3.7991e-04
# Epoch 194/250
# 630/630 [==============================] - ETA: 0s - loss: 7.3828 - mae: 7.3828
# Epoch 00194: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.3828 - mae: 7.3828 - val_loss: 6.9434 - val_mae: 6.9434 - lr: 3.7991e-04
# Epoch 195/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4417 - mae: 7.4417
# Epoch 00195: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 432ms/step - loss: 7.4417 - mae: 7.4417 - val_loss: 7.2161 - val_mae: 7.2161 - lr: 3.7991e-04
# Epoch 196/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4905 - mae: 7.4905
# Epoch 00196: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.4905 - mae: 7.4905 - val_loss: 6.6937 - val_mae: 6.6937 - lr: 3.7991e-04
# Epoch 197/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4176 - mae: 7.4176
# Epoch 00197: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.4176 - mae: 7.4176 - val_loss: 6.7461 - val_mae: 6.7461 - lr: 3.7991e-04
# Epoch 198/250
# 630/630 [==============================] - ETA: 0s - loss: 7.4000 - mae: 7.4000
# Epoch 00198: ReduceLROnPlateau reducing learning rate to 0.0003039296949282289.
#
# Epoch 00198: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 432ms/step - loss: 7.4000 - mae: 7.4000 - val_loss: 6.7199 - val_mae: 6.7199 - lr: 3.7991e-04
# Epoch 199/250
# 630/630 [==============================] - ETA: 0s - loss: 7.3661 - mae: 7.3661
# Epoch 00199: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 433ms/step - loss: 7.3661 - mae: 7.3661 - val_loss: 6.7849 - val_mae: 6.7849 - lr: 3.0393e-04
# Epoch 200/250
# 630/630 [==============================] - ETA: 0s - loss: 7.3922 - mae: 7.3922
# Epoch 00200: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 433ms/step - loss: 7.3922 - mae: 7.3922 - val_loss: 6.9145 - val_mae: 6.9145 - lr: 3.0393e-04
# Epoch 201/250
# 630/630 [==============================] - ETA: 0s - loss: 7.1883 - mae: 7.1883
# Epoch 00201: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 432ms/step - loss: 7.1883 - mae: 7.1883 - val_loss: 6.8978 - val_mae: 6.8978 - lr: 3.0393e-04
# Epoch 202/250
# 630/630 [==============================] - ETA: 0s - loss: 7.3665 - mae: 7.3665
# Epoch 00202: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.3665 - mae: 7.3665 - val_loss: 6.7817 - val_mae: 6.7817 - lr: 3.0393e-04
# Epoch 203/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2904 - mae: 7.2904
# Epoch 00203: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.2904 - mae: 7.2904 - val_loss: 6.6779 - val_mae: 6.6779 - lr: 3.0393e-04
# Epoch 204/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2929 - mae: 7.2929
# Epoch 00204: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 433ms/step - loss: 7.2929 - mae: 7.2929 - val_loss: 6.9239 - val_mae: 6.9239 - lr: 3.0393e-04
# Epoch 205/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2545 - mae: 7.2545
# Epoch 00205: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.2545 - mae: 7.2545 - val_loss: 6.7495 - val_mae: 6.7495 - lr: 3.0393e-04
# Epoch 206/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2971 - mae: 7.2971
# Epoch 00206: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 433ms/step - loss: 7.2971 - mae: 7.2971 - val_loss: 6.6805 - val_mae: 6.6805 - lr: 3.0393e-04
# Epoch 207/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2938 - mae: 7.2938
# Epoch 00207: ReduceLROnPlateau reducing learning rate to 0.00024314376059919596.
#
# Epoch 00207: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.2938 - mae: 7.2938 - val_loss: 6.8370 - val_mae: 6.8370 - lr: 3.0393e-04
# Epoch 208/250
# 630/630 [==============================] - ETA: 0s - loss: 7.3240 - mae: 7.3240
# Epoch 00208: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.3240 - mae: 7.3240 - val_loss: 6.7385 - val_mae: 6.7385 - lr: 2.4314e-04
# Epoch 209/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2922 - mae: 7.2922
# Epoch 00209: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.2922 - mae: 7.2922 - val_loss: 6.7569 - val_mae: 6.7569 - lr: 2.4314e-04
# Epoch 210/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2747 - mae: 7.2747
# Epoch 00210: val_loss did not improve from 6.65611
# 630/630 [==============================] - 272s 432ms/step - loss: 7.2747 - mae: 7.2747 - val_loss: 6.6980 - val_mae: 6.6980 - lr: 2.4314e-04
# Epoch 211/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2619 - mae: 7.2619
# Epoch 00211: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.2619 - mae: 7.2619 - val_loss: 6.9098 - val_mae: 6.9098 - lr: 2.4314e-04
# Epoch 212/250
# 630/630 [==============================] - ETA: 0s - loss: 7.1714 - mae: 7.1714
# Epoch 00212: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.1714 - mae: 7.1714 - val_loss: 6.8970 - val_mae: 6.8970 - lr: 2.4314e-04
# Epoch 213/250
# 630/630 [==============================] - ETA: 0s - loss: 7.2348 - mae: 7.2348
# Epoch 00213: val_loss did not improve from 6.65611
# 630/630 [==============================] - 273s 433ms/step - loss: 7.2348 - mae: 7.2348 - val_loss: 7.1480 - val_mae: 7.1480 - lr: 2.4314e-04

# %% [markdown]
# ## imports

# %%
import numpy as np
import pandas as pd
import os
from itertools import cycle

from keras import Input
from keras.applications.inception_v3 import InceptionV3
from keras.layers import Dense, Flatten, AveragePooling2D, concatenate
from keras.optimizer_v2.adam import Adam
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, LearningRateScheduler
from flow_dataframe import flow_from_dataframe

# hyperparameters
NUM_EPOCHS = 150
BATCH_SIZE_TRAIN = 16
BATCH_SIZE_VAL = 16


# default size of InceptionResNetV2
IMG_SIZE = (299, 299)

# %% [markdown]
# ## Preprocessing Image Data

# %%
# Generate batches of tensor image data with real-time data augmentation. The data will be looped over (in batches).

core_idg = ImageDataGenerator(zoom_range=0.2,
                              fill_mode='nearest',
                              featurewise_center=False,  # set input mean to 0 over the dataset
                              samplewise_center=False,  # set each sample mean to 0
                              featurewise_std_normalization=False,  # divide inputs by std of the dataset
                              samplewise_std_normalization=False,  # divide each input by its std
                              zca_whitening=False,  # apply ZCA whitening
                              rotation_range=25,  # randomly rotate images in the range (degrees, 0 to 180)
                              width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
                              height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
                              horizontal_flip=True,  # randomly flip images
                              vertical_flip=False)

val_idg = ImageDataGenerator(width_shift_range=0.25, height_shift_range=0.25, horizontal_flip=True)

# %% [markdown]
# ## Creating Data Generators
# ### Reading RSNA Boneage Dataset

# %%
class_str_col = 'boneage'
gender_str_col = 'male'

base_bone_dir = os.path.join('rsna-bone-age')
boneage_df = pd.read_csv(os.path.join(base_bone_dir, 'boneage-training-dataset.csv'))
boneage_df['path'] = boneage_df['id'].map(lambda x: os.path.join(base_bone_dir,
                                                         'boneage-training-dataset', 
                                                         'boneage-training-dataset', 
                                                         '{}.png'.format(x)))

boneage_df['exists'] = boneage_df['path'].map(os.path.exists)
print(boneage_df['exists'].sum(), 'images found of', boneage_df.shape[0], 'total')

boneage_df[gender_str_col] = boneage_df[gender_str_col].map(lambda x: np.array([1]) if x else np.array([0])) # map boolean values to 1 and 0

train_df_boneage, valid_df_boneage = train_test_split(boneage_df, test_size=0.2,
                                                      random_state=2018)  # ,stratify=boneage_df['boneage_category'])
print('train', train_df_boneage.shape[0], 'validation', valid_df_boneage.shape[0])

train_gen_boneage = flow_from_dataframe(core_idg, train_df_boneage, path_col='path', y_col=class_str_col,
                                        target_size=IMG_SIZE,
                                        color_mode='rgb', batch_size=BATCH_SIZE_TRAIN)

# used a fixed dataset for evaluating the algorithm
valid_gen_boneage = flow_from_dataframe(core_idg, valid_df_boneage, path_col='path', y_col=class_str_col,
                                        target_size=IMG_SIZE,
                                        color_mode='rgb',
                                        batch_size=BATCH_SIZE_VAL)  # we can use much larger batches for evaluation
# Out:
# 12611 images found of 12611 total
# train 10088 validation 2523
# flow_from_dataframe() -->
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 10088 images
# flow_from_dataframe() <--
# flow_from_dataframe() -->
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 2523 images
# flow_from_dataframe() <--

# %% [markdown]
# ## Defining callback functions and generators

# %%
weight_path = "{}_weights.best.hdf5".format('bone_age')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                            save_best_only=True, mode='min', save_weights_only=True)

early = EarlyStopping(monitor="val_loss", mode="min",
                      patience=15)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=15, verbose=1,
                                   save_best_only=True, mode='auto', min_delta=0.0001, cooldown=5)

optimizer = Adam(learning_rate = 0.007)


def combined_generators(image_generator, gender_data, batch_size):
    gender_generator = cycle(batch(gender_data, batch_size))
    while True:
        nextImage = next(image_generator)
        nextGender = next(gender_generator)
        nextGender=np.asarray(nextGender).astype(int)
        assert len(nextImage[0]) == len(nextGender)
        yield [nextImage[0], nextGender], nextImage[1]


def batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

train_gen_wrapper = combined_generators(train_gen_boneage, train_df_boneage[gender_str_col], BATCH_SIZE_TRAIN)
val_gen_wrapper = combined_generators(valid_gen_boneage, valid_df_boneage[gender_str_col], BATCH_SIZE_VAL)

# %% [markdown]
# ## Building Model

# %%
i1 = Input(shape=(299, 299, 3), name='input_img')
i2 = Input(shape=(1), name='input_gender')
base = InceptionV3(input_tensor=i1, input_shape=(299, 299, 3), include_top=False, weights=None)

feature_img = base.get_layer(name='mixed10').output
feature_img = AveragePooling2D((2, 2))(feature_img)
feature_img = Flatten()(feature_img)
feature_gender = Dense(32, activation='relu')(i2)
feature = concatenate([feature_img, feature_gender], axis=1)

o = Dense(1000, activation='relu')(feature)
o = Dense(1000, activation='relu')(o)
o = Dense(1)(o)
model = Model(inputs=[i1, i2], outputs=o)
model.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mae'])

# %%
model.summary()

# %%
model.load_weights(weight_path)

# %%
history = model.fit(train_gen_wrapper, validation_data=val_gen_wrapper,
                              epochs=NUM_EPOCHS, steps_per_epoch=len(train_gen_boneage),
                              validation_steps=len(valid_gen_boneage),
                              callbacks=[early, reduceLROnPlat, checkpoint])

model.save('./model_save_here/saved_model')
# Out:
# Epoch 1/150
# 631/631 [==============================] - ETA: 0s - loss: 12.7455 - mae: 12.7455
# Epoch 00001: val_loss improved from inf to 16.19649, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 886s 1s/step - loss: 12.7455 - mae: 12.7455 - val_loss: 16.1965 - val_mae: 16.1965 - lr: 0.0070
# Epoch 2/150
# 631/631 [==============================] - ETA: 0s - loss: 13.1376 - mae: 13.1376
# Epoch 00002: val_loss did not improve from 16.19649
# 631/631 [==============================] - 767s 1s/step - loss: 13.1376 - mae: 13.1376 - val_loss: 16.4209 - val_mae: 16.4209 - lr: 0.0070
# Epoch 3/150
# 631/631 [==============================] - ETA: 0s - loss: 12.4162 - mae: 12.4162
# Epoch 00003: val_loss improved from 16.19649 to 13.16243, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 720s 1s/step - loss: 12.4162 - mae: 12.4162 - val_loss: 13.1624 - val_mae: 13.1624 - lr: 0.0070
# Epoch 4/150
# 631/631 [==============================] - ETA: 0s - loss: 12.4025 - mae: 12.4025
# Epoch 00004: val_loss did not improve from 13.16243
# 631/631 [==============================] - 703s 1s/step - loss: 12.4025 - mae: 12.4025 - val_loss: 13.6855 - val_mae: 13.6855 - lr: 0.0070
# Epoch 5/150
# 631/631 [==============================] - ETA: 0s - loss: 12.1560 - mae: 12.1560
# Epoch 00005: val_loss did not improve from 13.16243
# 631/631 [==============================] - 639s 1s/step - loss: 12.1560 - mae: 12.1560 - val_loss: 15.0182 - val_mae: 15.0182 - lr: 0.0070
# Epoch 6/150
# 631/631 [==============================] - ETA: 0s - loss: 12.0143 - mae: 12.0143
# Epoch 00006: val_loss did not improve from 13.16243
# 631/631 [==============================] - 580s 921ms/step - loss: 12.0143 - mae: 12.0143 - val_loss: 13.7005 - val_mae: 13.7005 - lr: 0.0070
# Epoch 7/150
# 631/631 [==============================] - ETA: 0s - loss: 11.9784 - mae: 11.9784
# Epoch 00007: val_loss did not improve from 13.16243
# 631/631 [==============================] - 604s 958ms/step - loss: 11.9784 - mae: 11.9784 - val_loss: 13.7410 - val_mae: 13.7410 - lr: 0.0070
# Epoch 8/150
# 631/631 [==============================] - ETA: 0s - loss: 11.9440 - mae: 11.9440
# Epoch 00008: val_loss did not improve from 13.16243
# 631/631 [==============================] - 609s 966ms/step - loss: 11.9440 - mae: 11.9440 - val_loss: 14.0387 - val_mae: 14.0387 - lr: 0.0070
# Epoch 9/150
# 631/631 [==============================] - ETA: 0s - loss: 11.8122 - mae: 11.8122
# Epoch 00009: val_loss did not improve from 13.16243
# 631/631 [==============================] - 618s 980ms/step - loss: 11.8122 - mae: 11.8122 - val_loss: 24.8870 - val_mae: 24.8870 - lr: 0.0070
# Epoch 10/150
# 631/631 [==============================] - ETA: 0s - loss: 11.6255 - mae: 11.6255
# Epoch 00010: val_loss did not improve from 13.16243
# 631/631 [==============================] - 734s 1s/step - loss: 11.6255 - mae: 11.6255 - val_loss: 14.6196 - val_mae: 14.6196 - lr: 0.0070
# Epoch 11/150
# 631/631 [==============================] - ETA: 0s - loss: 11.4795 - mae: 11.4795
# Epoch 00011: val_loss did not improve from 13.16243
# 631/631 [==============================] - 628s 996ms/step - loss: 11.4795 - mae: 11.4795 - val_loss: 15.1871 - val_mae: 15.1871 - lr: 0.0070
# Epoch 12/150
# 631/631 [==============================] - ETA: 0s - loss: 11.5244 - mae: 11.5244
# Epoch 00012: val_loss improved from 13.16243 to 12.66210, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 620s 984ms/step - loss: 11.5244 - mae: 11.5244 - val_loss: 12.6621 - val_mae: 12.6621 - lr: 0.0070
# Epoch 13/150
# 631/631 [==============================] - ETA: 0s - loss: 11.5767 - mae: 11.5767
# Epoch 00013: val_loss improved from 12.66210 to 11.08010, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 642s 1s/step - loss: 11.5767 - mae: 11.5767 - val_loss: 11.0801 - val_mae: 11.0801 - lr: 0.0070
# Epoch 14/150
# 631/631 [==============================] - ETA: 0s - loss: 11.6148 - mae: 11.6148
# Epoch 00014: val_loss did not improve from 11.08010
# 631/631 [==============================] - 638s 1s/step - loss: 11.6148 - mae: 11.6148 - val_loss: 15.0231 - val_mae: 15.0231 - lr: 0.0070
# Epoch 15/150
# 631/631 [==============================] - ETA: 0s - loss: 11.5876 - mae: 11.5876
# Epoch 00015: val_loss did not improve from 11.08010
# 631/631 [==============================] - 624s 990ms/step - loss: 11.5876 - mae: 11.5876 - val_loss: 15.6090 - val_mae: 15.6090 - lr: 0.0070
# Epoch 16/150
# 631/631 [==============================] - ETA: 0s - loss: 11.3707 - mae: 11.3707
# Epoch 00016: val_loss did not improve from 11.08010
# 631/631 [==============================] - 704s 1s/step - loss: 11.3707 - mae: 11.3707 - val_loss: 12.0305 - val_mae: 12.0305 - lr: 0.0070
# Epoch 17/150
# 631/631 [==============================] - ETA: 0s - loss: 11.2981 - mae: 11.2981
# Epoch 00017: val_loss did not improve from 11.08010
# 631/631 [==============================] - 619s 982ms/step - loss: 11.2981 - mae: 11.2981 - val_loss: 11.1993 - val_mae: 11.1993 - lr: 0.0070
# Epoch 18/150
# 631/631 [==============================] - ETA: 0s - loss: 11.3620 - mae: 11.3620
# Epoch 00018: val_loss did not improve from 11.08010
# 631/631 [==============================] - 617s 979ms/step - loss: 11.3620 - mae: 11.3620 - val_loss: 14.8567 - val_mae: 14.8567 - lr: 0.0070
# Epoch 19/150
# 631/631 [==============================] - ETA: 0s - loss: 11.1172 - mae: 11.1172
# Epoch 00019: val_loss did not improve from 11.08010
# 631/631 [==============================] - 618s 981ms/step - loss: 11.1172 - mae: 11.1172 - val_loss: 12.1256 - val_mae: 12.1256 - lr: 0.0070
# Epoch 20/150
# 631/631 [==============================] - ETA: 0s - loss: 11.1592 - mae: 11.1592
# Epoch 00020: val_loss did not improve from 11.08010
# 631/631 [==============================] - 625s 992ms/step - loss: 11.1592 - mae: 11.1592 - val_loss: 12.0889 - val_mae: 12.0889 - lr: 0.0070
# Epoch 21/150
# 631/631 [==============================] - ETA: 0s - loss: 11.3104 - mae: 11.3104
# Epoch 00021: val_loss improved from 11.08010 to 10.97916, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 695s 1s/step - loss: 11.3104 - mae: 11.3104 - val_loss: 10.9792 - val_mae: 10.9792 - lr: 0.0070
# Epoch 22/150
# 631/631 [==============================] - ETA: 0s - loss: 10.8547 - mae: 10.8547
# Epoch 00022: val_loss did not improve from 10.97916
# 631/631 [==============================] - 669s 1s/step - loss: 10.8547 - mae: 10.8547 - val_loss: 12.6460 - val_mae: 12.6460 - lr: 0.0070
# Epoch 23/150
# 631/631 [==============================] - ETA: 0s - loss: 10.9064 - mae: 10.9064
# Epoch 00023: val_loss did not improve from 10.97916
# 631/631 [==============================] - 611s 969ms/step - loss: 10.9064 - mae: 10.9064 - val_loss: 13.8820 - val_mae: 13.8820 - lr: 0.0070
# Epoch 24/150
# 631/631 [==============================] - ETA: 0s - loss: 10.8315 - mae: 10.8315
# Epoch 00024: val_loss did not improve from 10.97916
# 631/631 [==============================] - 618s 981ms/step - loss: 10.8315 - mae: 10.8315 - val_loss: 11.4829 - val_mae: 11.4829 - lr: 0.0070
# Epoch 25/150
# 631/631 [==============================] - ETA: 0s - loss: 10.7975 - mae: 10.7975
# Epoch 00025: val_loss did not improve from 10.97916
# 631/631 [==============================] - 623s 989ms/step - loss: 10.7975 - mae: 10.7975 - val_loss: 11.4774 - val_mae: 11.4774 - lr: 0.0070
# Epoch 26/150
# 631/631 [==============================] - ETA: 0s - loss: 10.9309 - mae: 10.9309
# Epoch 00026: val_loss did not improve from 10.97916
# 631/631 [==============================] - 682s 1s/step - loss: 10.9309 - mae: 10.9309 - val_loss: 11.7126 - val_mae: 11.7126 - lr: 0.0070
# Epoch 27/150
# 631/631 [==============================] - ETA: 0s - loss: 10.7897 - mae: 10.7897
# Epoch 00027: val_loss improved from 10.97916 to 10.96777, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 708s 1s/step - loss: 10.7897 - mae: 10.7897 - val_loss: 10.9678 - val_mae: 10.9678 - lr: 0.0070
# Epoch 28/150
# 631/631 [==============================] - ETA: 0s - loss: 10.9253 - mae: 10.9253
# Epoch 00028: val_loss did not improve from 10.96777
# 631/631 [==============================] - 592s 939ms/step - loss: 10.9253 - mae: 10.9253 - val_loss: 12.0901 - val_mae: 12.0901 - lr: 0.0070
# Epoch 29/150
# 631/631 [==============================] - ETA: 0s - loss: 10.6714 - mae: 10.6714
# Epoch 00029: val_loss did not improve from 10.96777
# 631/631 [==============================] - 596s 945ms/step - loss: 10.6714 - mae: 10.6714 - val_loss: 20.1394 - val_mae: 20.1394 - lr: 0.0070
# Epoch 30/150
# 631/631 [==============================] - ETA: 0s - loss: 10.5177 - mae: 10.5177
# Epoch 00030: val_loss did not improve from 10.96777
# 631/631 [==============================] - 821s 1s/step - loss: 10.5177 - mae: 10.5177 - val_loss: 11.9718 - val_mae: 11.9718 - lr: 0.0070
# Epoch 31/150
# 631/631 [==============================] - ETA: 0s - loss: 10.7300 - mae: 10.7300
# Epoch 00031: val_loss did not improve from 10.96777
# 631/631 [==============================] - 816s 1s/step - loss: 10.7300 - mae: 10.7300 - val_loss: 11.3202 - val_mae: 11.3202 - lr: 0.0070
# Epoch 32/150
# 631/631 [==============================] - ETA: 0s - loss: 10.6102 - mae: 10.6102
# Epoch 00032: val_loss did not improve from 10.96777
# 631/631 [==============================] - 821s 1s/step - loss: 10.6102 - mae: 10.6102 - val_loss: 11.0738 - val_mae: 11.0738 - lr: 0.0070
# Epoch 33/150
# 631/631 [==============================] - ETA: 0s - loss: 10.5147 - mae: 10.5147
# Epoch 00033: val_loss did not improve from 10.96777
# 631/631 [==============================] - 794s 1s/step - loss: 10.5147 - mae: 10.5147 - val_loss: 12.9632 - val_mae: 12.9632 - lr: 0.0070
# Epoch 34/150
# 631/631 [==============================] - ETA: 0s - loss: 10.5210 - mae: 10.5210
# Epoch 00034: val_loss did not improve from 10.96777
# 631/631 [==============================] - 786s 1s/step - loss: 10.5210 - mae: 10.5210 - val_loss: 13.9736 - val_mae: 13.9736 - lr: 0.0070
# Epoch 35/150
# 631/631 [==============================] - ETA: 0s - loss: 10.5521 - mae: 10.5521
# Epoch 00035: val_loss improved from 10.96777 to 10.58559, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 808s 1s/step - loss: 10.5521 - mae: 10.5521 - val_loss: 10.5856 - val_mae: 10.5856 - lr: 0.0070
# Epoch 36/150
# 631/631 [==============================] - ETA: 0s - loss: 10.4731 - mae: 10.4731
# Epoch 00036: val_loss did not improve from 10.58559
# 631/631 [==============================] - 797s 1s/step - loss: 10.4731 - mae: 10.4731 - val_loss: 13.5904 - val_mae: 13.5904 - lr: 0.0070
# Epoch 37/150
# 631/631 [==============================] - ETA: 0s - loss: 10.6005 - mae: 10.6005
# Epoch 00037: val_loss did not improve from 10.58559
# 631/631 [==============================] - 785s 1s/step - loss: 10.6005 - mae: 10.6005 - val_loss: 14.3932 - val_mae: 14.3932 - lr: 0.0070
# Epoch 38/150
# 631/631 [==============================] - ETA: 0s - loss: 10.5897 - mae: 10.5897
# Epoch 00038: val_loss did not improve from 10.58559
# 631/631 [==============================] - 781s 1s/step - loss: 10.5897 - mae: 10.5897 - val_loss: 10.9188 - val_mae: 10.9188 - lr: 0.0070
# Epoch 39/150
# 631/631 [==============================] - ETA: 0s - loss: 10.3705 - mae: 10.3705
# Epoch 00039: val_loss did not improve from 10.58559
# 631/631 [==============================] - 805s 1s/step - loss: 10.3705 - mae: 10.3705 - val_loss: 11.4410 - val_mae: 11.4410 - lr: 0.0070
# Epoch 40/150
# 631/631 [==============================] - ETA: 0s - loss: 10.2245 - mae: 10.2245
# Epoch 00040: val_loss did not improve from 10.58559
# 631/631 [==============================] - 803s 1s/step - loss: 10.2245 - mae: 10.2245 - val_loss: 11.7098 - val_mae: 11.7098 - lr: 0.0070
# Epoch 41/150
# 631/631 [==============================] - ETA: 0s - loss: 10.2977 - mae: 10.2977
# Epoch 00041: val_loss did not improve from 10.58559
# 631/631 [==============================] - 821s 1s/step - loss: 10.2977 - mae: 10.2977 - val_loss: 12.0440 - val_mae: 12.0440 - lr: 0.0070
# Epoch 42/150
# 631/631 [==============================] - ETA: 0s - loss: 10.3459 - mae: 10.3459
# Epoch 00042: val_loss did not improve from 10.58559
# 631/631 [==============================] - 802s 1s/step - loss: 10.3459 - mae: 10.3459 - val_loss: 10.6982 - val_mae: 10.6982 - lr: 0.0070
# Epoch 43/150
# 631/631 [==============================] - ETA: 0s - loss: 10.3700 - mae: 10.3700
# Epoch 00043: val_loss did not improve from 10.58559
# 631/631 [==============================] - 818s 1s/step - loss: 10.3700 - mae: 10.3700 - val_loss: 10.6851 - val_mae: 10.6851 - lr: 0.0070
# Epoch 44/150
# 631/631 [==============================] - ETA: 0s - loss: 10.2995 - mae: 10.2995
# Epoch 00044: val_loss did not improve from 10.58559
# 631/631 [==============================] - 799s 1s/step - loss: 10.2995 - mae: 10.2995 - val_loss: 13.4753 - val_mae: 13.4753 - lr: 0.0070
# Epoch 45/150
# 631/631 [==============================] - ETA: 0s - loss: 10.0167 - mae: 10.0167
# Epoch 00045: val_loss did not improve from 10.58559
# 631/631 [==============================] - 816s 1s/step - loss: 10.0167 - mae: 10.0167 - val_loss: 11.6405 - val_mae: 11.6405 - lr: 0.0070
# Epoch 46/150
# 631/631 [==============================] - ETA: 0s - loss: 10.2380 - mae: 10.2380
# Epoch 00046: val_loss did not improve from 10.58559
# 631/631 [==============================] - 804s 1s/step - loss: 10.2380 - mae: 10.2380 - val_loss: 11.6367 - val_mae: 11.6367 - lr: 0.0070
# Epoch 47/150
# 631/631 [==============================] - ETA: 0s - loss: 10.1820 - mae: 10.1820
# Epoch 00047: val_loss improved from 10.58559 to 10.38151, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 812s 1s/step - loss: 10.1820 - mae: 10.1820 - val_loss: 10.3815 - val_mae: 10.3815 - lr: 0.0070
# Epoch 48/150
# 631/631 [==============================] - ETA: 0s - loss: 10.2465 - mae: 10.2465
# Epoch 00048: val_loss did not improve from 10.38151
# 631/631 [==============================] - 801s 1s/step - loss: 10.2465 - mae: 10.2465 - val_loss: 15.5481 - val_mae: 15.5481 - lr: 0.0070
# Epoch 49/150
# 631/631 [==============================] - ETA: 0s - loss: 10.0700 - mae: 10.0700
# Epoch 00049: val_loss did not improve from 10.38151
# 631/631 [==============================] - 804s 1s/step - loss: 10.0700 - mae: 10.0700 - val_loss: 11.0121 - val_mae: 11.0121 - lr: 0.0070
# Epoch 50/150
# 631/631 [==============================] - ETA: 0s - loss: 10.0546 - mae: 10.0546
# Epoch 00050: val_loss improved from 10.38151 to 10.24613, saving model to bone_age_weights.best.hdf5
# 631/631 [==============================] - 806s 1s/step - loss: 10.0546 - mae: 10.0546 - val_loss: 10.2461 - val_mae: 10.2461 - lr: 0.0070
# Epoch 51/150
# 631/631 [==============================] - ETA: 0s - loss: 10.0219 - mae: 10.0219
# Epoch 00051: val_loss did not improve from 10.24613
# 631/631 [==============================] - 779s 1s/step - loss: 10.0219 - mae: 10.0219 - val_loss: 12.1003 - val_mae: 12.1003 - lr: 0.0070
# Epoch 52/150
# 631/631 [==============================] - ETA: 0s - loss: 9.9090 - mae: 9.9090
# Epoch 00052: val_loss did not improve from 10.24613
# 631/631 [==============================] - 770s 1s/step - loss: 9.9090 - mae: 9.9090 - val_loss: 16.7498 - val_mae: 16.7498 - lr: 0.0070
# Epoch 53/150
# 631/631 [==============================] - ETA: 0s - loss: 9.8697 - mae: 9.8697
# Epoch 00053: val_loss did not improve from 10.24613
# 631/631 [==============================] - 776s 1s/step - loss: 9.8697 - mae: 9.8697 - val_loss: 11.4558 - val_mae: 11.4558 - lr: 0.0070
# Epoch 54/150
# 631/631 [==============================] - ETA: 0s - loss: 10.3180 - mae: 10.3180
# Epoch 00054: val_loss did not improve from 10.24613
# 631/631 [==============================] - 770s 1s/step - loss: 10.3180 - mae: 10.3180 - val_loss: 10.3922 - val_mae: 10.3922 - lr: 0.0070
# Epoch 55/150
# 631/631 [==============================] - ETA: 0s - loss: 9.9601 - mae: 9.9601
# Epoch 00055: val_loss did not improve from 10.24613
# 631/631 [==============================] - 768s 1s/step - loss: 9.9601 - mae: 9.9601 - val_loss: 11.6651 - val_mae: 11.6651 - lr: 0.0070
# Epoch 56/150
# 631/631 [==============================] - ETA: 0s - loss: 10.0106 - mae: 10.0106
# Epoch 00056: val_loss did not improve from 10.24613
# 631/631 [==============================] - 717s 1s/step - loss: 10.0106 - mae: 10.0106 - val_loss: 10.6740 - val_mae: 10.6740 - lr: 0.0070
# Epoch 57/150
# 631/631 [==============================] - ETA: 0s - loss: 9.8270 - mae: 9.8270
# Epoch 00057: val_loss did not improve from 10.24613
# 631/631 [==============================] - 683s 1s/step - loss: 9.8270 - mae: 9.8270 - val_loss: 10.6263 - val_mae: 10.6263 - lr: 0.0070
# Epoch 58/150
# 631/631 [==============================] - ETA: 0s - loss: 10.0210 - mae: 10.0210
# Epoch 00058: val_loss did not improve from 10.24613
# 631/631 [==============================] - 671s 1s/step - loss: 10.0210 - mae: 10.0210 - val_loss: 10.8172 - val_mae: 10.8172 - lr: 0.0070
# Epoch 59/150
# 631/631 [==============================] - ETA: 0s - loss: 9.9157 - mae: 9.9157
# Epoch 00059: val_loss did not improve from 10.24613
# 631/631 [==============================] - 685s 1s/step - loss: 9.9157 - mae: 9.9157 - val_loss: 11.2681 - val_mae: 11.2681 - lr: 0.0070
# Epoch 60/150
# 631/631 [==============================] - ETA: 0s - loss: 9.8305 - mae: 9.8305
# Epoch 00060: val_loss did not improve from 10.24613
# 631/631 [==============================] - 726s 1s/step - loss: 9.8305 - mae: 9.8305 - val_loss: 10.8568 - val_mae: 10.8568 - lr: 0.0070
# Epoch 61/150
# 631/631 [==============================] - ETA: 0s - loss: 9.8698 - mae: 9.8698
# Epoch 00061: val_loss did not improve from 10.24613
# 631/631 [==============================] - 667s 1s/step - loss: 9.8698 - mae: 9.8698 - val_loss: 10.5000 - val_mae: 10.5000 - lr: 0.0070
# Epoch 62/150
# 631/631 [==============================] - ETA: 0s - loss: 9.8437 - mae: 9.8437
# Epoch 00062: val_loss did not improve from 10.24613
# 631/631 [==============================] - 656s 1s/step - loss: 9.8437 - mae: 9.8437 - val_loss: 11.6947 - val_mae: 11.6947 - lr: 0.0070
# Epoch 63/150
# 631/631 [==============================] - ETA: 0s - loss: 9.7291 - mae: 9.7291
# Epoch 00063: val_loss did not improve from 10.24613
# 631/631 [==============================] - 658s 1s/step - loss: 9.7291 - mae: 9.7291 - val_loss: 10.6064 - val_mae: 10.6064 - lr: 0.0070
# Epoch 64/150
# 631/631 [==============================] - ETA: 0s - loss: 9.7396 - mae: 9.7396
# Epoch 00064: val_loss did not improve from 10.24613
# 631/631 [==============================] - 662s 1s/step - loss: 9.7396 - mae: 9.7396 - val_loss: 10.2628 - val_mae: 10.2628 - lr: 0.0070
# Epoch 65/150
# 631/631 [==============================] - ETA: 0s - loss: 9.8094 - mae: 9.8094
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.00560000017285347.
#
# Epoch 00065: val_loss did not improve from 10.24613
# 631/631 [==============================] - 740s 1s/step - loss: 9.8094 - mae: 9.8094 - val_loss: 11.6232 - val_mae: 11.6232 - lr: 0.0070
# INFO:tensorflow:Assets written to: ./model_save_here/saved_model\assets

# %%
import re, math
import numpy as np
import matplotlib.pyplot as plt
from functools import partial
from sklearn.model_selection import train_test_split
from kaggle_datasets import KaggleDatasets
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Dense, Flatten, AveragePooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
# Out:
# 2022-04-10 19:52:39.088280: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-04-10 19:52:39.088385: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
# Out:
# Device: grpc://10.0.0.2:8470
# 2022-04-10 19:52:43.149538: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-10 19:52:43.152122: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2022-04-10 19:52:43.152152: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-10 19:52:43.152176: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ccacb0274135): /proc/driver/nvidia/version does not exist
# 2022-04-10 19:52:43.154269: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-10 19:52:43.155572: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-10 19:52:43.161838: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-10 19:52:43.184534: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-04-10 19:52:43.184575: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30022}
# 2022-04-10 19:52:43.209663: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-04-10 19:52:43.209707: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30022}
# 2022-04-10 19:52:43.210952: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30022
# Number of replicas: 8

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
IMAGE_SIZE = [512, 512]
GCS_PATH = KaggleDatasets().get_gcs_path()
HEIGHT = 512
WIDTH = 512
CHANNELS = 3

# %%
def decode_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.image.resize(image, IMAGE_SIZE)
    return image

# %%
def read_tfrecord(example):
    tfrecord_format = {
        'image': tf.io.FixedLenFeature([], tf.string),
        'id': tf.io.FixedLenFeature([], tf.string),
        'boneage': tf.io.FixedLenFeature([], tf.int64),
        'male': tf.io.FixedLenFeature([], tf.int64)
    }
    example = tf.io.parse_single_example(example, tfrecord_format)
    image = decode_image(example['image'])
    boneAge = tf.cast(example['boneage'], tf.int32)
    male = tf.cast(example['male'], tf.bool)
    inputs = {}
    inputs['image'] = image
    inputs['gender'] = male
    return inputs, boneAge

# %%
def load_dataset(filenames):
    ignore_order = tf.data.Options()
    ignore_order.experimental_deterministic = False # disable order, increase speed
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE) # automatically interleaves reads from multiple files
    dataset = dataset.with_options(ignore_order) # uses data as soon as it streams in, rather than in its original order
    dataset = dataset.map(partial(read_tfrecord), num_parallel_calls=AUTOTUNE)
    return dataset

# %%
TRAINING_FILENAMES, VALID_FILENAMES = train_test_split(
    tf.io.gfile.glob(GCS_PATH + '/bone_age_tfrecords/*.tfrec'),
    test_size=0.2, random_state=2018
)
# Out:
# 2022-04-10 19:52:50.101462: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
def custom_data_augment(inputs, boneAge):
    image = inputs['image']
    p_rotation = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    # Shear
    if p_shear > .2:
        if p_shear > .6:
            image = transform_shear(image, HEIGHT, shear=20.)
        else:
            image = transform_shear(image, HEIGHT, shear=-20.)
            
    # Rotation
    if p_rotation > .2:
        if p_rotation > .6:
            image = transform_rotation(image, HEIGHT, rotation=45.)
        else:
            image = transform_rotation(image, HEIGHT, rotation=-45.)
            
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k=3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k=2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k=1) # rotate 90º
        
    # Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower=.7, upper=1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower=.8, upper=1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta=.1)
        
    # Crops
    if p_crop > .7:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .4:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])
            
    image = tf.image.resize(image, size=[HEIGHT, WIDTH])

    inputs['image'] = image
    return inputs, boneAge

# %%
# data augmentation @cdeotte kernel: https://www.kaggle.com/cdeotte/rotation-augmentation-gpu-tpu-0-96
def transform_rotation(image, height, rotation):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly rotated
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    rotation = rotation * tf.random.uniform([1],dtype='float32')
    # CONVERT DEGREES TO RADIANS
    rotation = math.pi * rotation / 180.
    
    # ROTATION MATRIX
    c1 = tf.math.cos(rotation)
    s1 = tf.math.sin(rotation)
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    rotation_matrix = tf.reshape(tf.concat([c1,s1,zero, -s1,c1,zero, zero,zero,one],axis=0),[3,3])

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(rotation_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

def transform_shear(image, height, shear):
    # input image - is one image of size [dim,dim,3] not a batch of [b,dim,dim,3]
    # output - image randomly sheared
    DIM = height
    XDIM = DIM%2 #fix for size 331
    
    shear = shear * tf.random.uniform([1],dtype='float32')
    shear = math.pi * shear / 180.
        
    # SHEAR MATRIX
    one = tf.constant([1],dtype='float32')
    zero = tf.constant([0],dtype='float32')
    c2 = tf.math.cos(shear)
    s2 = tf.math.sin(shear)
    shear_matrix = tf.reshape(tf.concat([one,s2,zero, zero,c2,zero, zero,zero,one],axis=0),[3,3])    

    # LIST DESTINATION PIXEL INDICES
    x = tf.repeat( tf.range(DIM//2,-DIM//2,-1), DIM )
    y = tf.tile( tf.range(-DIM//2,DIM//2),[DIM] )
    z = tf.ones([DIM*DIM],dtype='int32')
    idx = tf.stack( [x,y,z] )
    
    # ROTATE DESTINATION PIXELS ONTO ORIGIN PIXELS
    idx2 = K.dot(shear_matrix,tf.cast(idx,dtype='float32'))
    idx2 = K.cast(idx2,dtype='int32')
    idx2 = K.clip(idx2,-DIM//2+XDIM+1,DIM//2)
    
    # FIND ORIGIN PIXEL VALUES 
    idx3 = tf.stack( [DIM//2-idx2[0,], DIM//2-1+idx2[1,]] )
    d = tf.gather_nd(image, tf.transpose(idx3))
        
    return tf.reshape(d,[DIM,DIM,3])

# %%
def get_training_dataset():
    dataset = load_dataset(TRAINING_FILENAMES)  
    dataset = dataset.map(custom_data_augment, num_parallel_calls=AUTOTUNE)  
    dataset = dataset.repeat()
    dataset = dataset.shuffle(1024)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

# %%
def get_validation_dataset():
    dataset = load_dataset(VALID_FILENAMES) 
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

# %%
def count_data_items(filenames):
    n = [int(re.compile(r"-([0-9]*)\.").search(filename).group(1)) for filename in filenames]
    return np.sum(n)

# %%
NUM_TRAINING_IMAGES = count_data_items(TRAINING_FILENAMES)
NUM_VALIDATION_IMAGES = count_data_items(VALID_FILENAMES)

print('Dataset: {} training images, {} validation images'.format(
    NUM_TRAINING_IMAGES, NUM_VALIDATION_IMAGES))
# Out:
# Dataset: 10088 training images, 2523 validation images

# %%
bestLr = 0.0107977516232771
weight_path = "{}_weights.best.hdf5".format('bone_age')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                            save_best_only=True, mode='min', save_weights_only=True)

early = EarlyStopping(monitor="val_loss", mode="min",
                      patience=20)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, verbose=1,
                                   save_best_only=True, mode='auto', min_delta=0.0001, cooldown=5)
optimizer = Adam(learning_rate = bestLr, beta_1 = 0.9, beta_2 = 0.999, epsilon = 0.1)
callBacks = [early, reduceLROnPlat, checkpoint]

# %%
with strategy.scope():       
    i1 = Input(shape=(512, 512, 3), name='image')
    i2 = Input(shape=(1), name='gender')
    base = InceptionV3(input_tensor=i1, input_shape=(512, 512, 3), include_top=False, weights=None)

    feature_img = base.get_layer(name='mixed10').output
    feature_img = AveragePooling2D((2, 2))(feature_img)
    feature_img = Flatten()(feature_img)
    feature_gender = Dense(32, activation='relu')(i2)
    feature = concatenate([feature_img, feature_gender], axis=1)

    o = Dense(1000, activation='relu')(feature)
    o = Dense(1000, activation='relu')(o)
    o = Dense(1)(o)
    model = Model(inputs=[i1, i2], outputs=o)
    model.compile(loss='mean_absolute_error', optimizer=optimizer, metrics=['mae'])

# %%
train_dataset = get_training_dataset()
valid_dataset = get_validation_dataset()

# %%
STEPS_PER_EPOCH = NUM_TRAINING_IMAGES // BATCH_SIZE
VALID_STEPS = NUM_VALIDATION_IMAGES // BATCH_SIZE

# %%
initalHistory = model.fit(train_dataset, 
                    steps_per_epoch=STEPS_PER_EPOCH, 
                    epochs=250,
                    validation_data=valid_dataset,
                    validation_steps=VALID_STEPS,
                    callbacks = callBacks)
# Out:
# Epoch 1/250
# 78/78 [==============================] - 161s 1s/step - loss: 57.8456 - mae: 57.8456 - val_loss: 76.1205 - val_mae: 76.1205
#
# Epoch 00001: val_loss improved from inf to 76.12054, saving model to bone_age_weights.best.hdf5
# Epoch 2/250
# 78/78 [==============================] - 54s 696ms/step - loss: 32.8817 - mae: 32.8817 - val_loss: 49.2461 - val_mae: 49.2461
#
# Epoch 00002: val_loss improved from 76.12054 to 49.24606, saving model to bone_age_weights.best.hdf5
# Epoch 3/250
# 78/78 [==============================] - 51s 657ms/step - loss: 32.9385 - mae: 32.9385 - val_loss: 37.1134 - val_mae: 37.1134
#
# Epoch 00003: val_loss improved from 49.24606 to 37.11338, saving model to bone_age_weights.best.hdf5
# Epoch 4/250
# 78/78 [==============================] - 48s 605ms/step - loss: 32.8358 - mae: 32.8358 - val_loss: 51.5911 - val_mae: 51.5911
#
# Epoch 00004: val_loss did not improve from 37.11338
# Epoch 5/250
# 78/78 [==============================] - 55s 713ms/step - loss: 32.1459 - mae: 32.1459 - val_loss: 40.9466 - val_mae: 40.9466
#
# Epoch 00005: val_loss did not improve from 37.11338
# Epoch 6/250
# 78/78 [==============================] - 55s 712ms/step - loss: 32.4011 - mae: 32.4011 - val_loss: 78.0057 - val_mae: 78.0057
#
# Epoch 00006: val_loss did not improve from 37.11338
# Epoch 7/250
# 78/78 [==============================] - 55s 713ms/step - loss: 31.2064 - mae: 31.2064 - val_loss: 90.9846 - val_mae: 90.9846
#
# Epoch 00007: val_loss did not improve from 37.11338
# Epoch 8/250
# 78/78 [==============================] - 56s 710ms/step - loss: 32.7472 - mae: 32.7472 - val_loss: 34.0876 - val_mae: 34.0876
#
# Epoch 00008: val_loss improved from 37.11338 to 34.08759, saving model to bone_age_weights.best.hdf5
# Epoch 9/250
# 78/78 [==============================] - 50s 643ms/step - loss: 31.2341 - mae: 31.2341 - val_loss: 35.5292 - val_mae: 35.5292
#
# Epoch 00009: val_loss did not improve from 34.08759
# Epoch 10/250
# 78/78 [==============================] - 55s 706ms/step - loss: 30.6735 - mae: 30.6735 - val_loss: 39.5343 - val_mae: 39.5343
#
# Epoch 00010: val_loss did not improve from 34.08759
# Epoch 11/250
# 78/78 [==============================] - 57s 729ms/step - loss: 29.8231 - mae: 29.8231 - val_loss: 33.0147 - val_mae: 33.0147
#
# Epoch 00011: val_loss improved from 34.08759 to 33.01470, saving model to bone_age_weights.best.hdf5
# Epoch 12/250
# 78/78 [==============================] - 52s 663ms/step - loss: 29.0786 - mae: 29.0786 - val_loss: 27.8082 - val_mae: 27.8082
#
# Epoch 00012: val_loss improved from 33.01470 to 27.80818, saving model to bone_age_weights.best.hdf5
# Epoch 13/250
# 78/78 [==============================] - 52s 672ms/step - loss: 28.3639 - mae: 28.3639 - val_loss: 26.6167 - val_mae: 26.6167
#
# Epoch 00013: val_loss improved from 27.80818 to 26.61666, saving model to bone_age_weights.best.hdf5
# Epoch 14/250
# 78/78 [==============================] - 54s 701ms/step - loss: 28.0550 - mae: 28.0550 - val_loss: 37.1653 - val_mae: 37.1653
#
# Epoch 00014: val_loss did not improve from 26.61666
# Epoch 15/250
# 78/78 [==============================] - 57s 730ms/step - loss: 28.7670 - mae: 28.7670 - val_loss: 41.2842 - val_mae: 41.2842
#
# Epoch 00015: val_loss did not improve from 26.61666
# Epoch 16/250
# 78/78 [==============================] - 56s 717ms/step - loss: 26.2391 - mae: 26.2391 - val_loss: 29.6634 - val_mae: 29.6634
#
# Epoch 00016: val_loss did not improve from 26.61666
# Epoch 17/250
# 78/78 [==============================] - 56s 714ms/step - loss: 25.9629 - mae: 25.9629 - val_loss: 30.9134 - val_mae: 30.9134
#
# Epoch 00017: val_loss did not improve from 26.61666
# Epoch 18/250
# 78/78 [==============================] - 53s 680ms/step - loss: 25.4517 - mae: 25.4517 - val_loss: 33.0000 - val_mae: 33.0000
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.008638201653957367.
#
# Epoch 00018: val_loss did not improve from 26.61666
# Epoch 19/250
# 78/78 [==============================] - 53s 687ms/step - loss: 25.2490 - mae: 25.2490 - val_loss: 27.2905 - val_mae: 27.2905
#
# Epoch 00019: val_loss did not improve from 26.61666
# Epoch 20/250
# 78/78 [==============================] - 54s 700ms/step - loss: 24.2929 - mae: 24.2929 - val_loss: 33.4148 - val_mae: 33.4148
#
# Epoch 00020: val_loss did not improve from 26.61666
# Epoch 21/250
# 78/78 [==============================] - 54s 699ms/step - loss: 23.6092 - mae: 23.6092 - val_loss: 38.8745 - val_mae: 38.8745
#
# Epoch 00021: val_loss did not improve from 26.61666
# Epoch 22/250
# 78/78 [==============================] - 55s 712ms/step - loss: 23.3235 - mae: 23.3235 - val_loss: 21.2061 - val_mae: 21.2061
#
# Epoch 00022: val_loss improved from 26.61666 to 21.20612, saving model to bone_age_weights.best.hdf5
# Epoch 23/250
# 78/78 [==============================] - 51s 656ms/step - loss: 23.1497 - mae: 23.1497 - val_loss: 61.5898 - val_mae: 61.5898
#
# Epoch 00023: val_loss did not improve from 21.20612
# Epoch 24/250
# 78/78 [==============================] - 55s 712ms/step - loss: 23.2127 - mae: 23.2127 - val_loss: 22.7370 - val_mae: 22.7370
#
# Epoch 00024: val_loss did not improve from 21.20612
# Epoch 25/250
# 78/78 [==============================] - 56s 723ms/step - loss: 22.2946 - mae: 22.2946 - val_loss: 20.3734 - val_mae: 20.3734
#
# Epoch 00025: val_loss improved from 21.20612 to 20.37339, saving model to bone_age_weights.best.hdf5
# Epoch 26/250
# 78/78 [==============================] - 50s 643ms/step - loss: 21.8226 - mae: 21.8226 - val_loss: 31.7427 - val_mae: 31.7427
#
# Epoch 00026: val_loss did not improve from 20.37339
# Epoch 27/250
# 78/78 [==============================] - 57s 739ms/step - loss: 21.6408 - mae: 21.6408 - val_loss: 51.4090 - val_mae: 51.4090
#
# Epoch 00027: val_loss did not improve from 20.37339
# Epoch 28/250
# 78/78 [==============================] - 57s 737ms/step - loss: 21.7604 - mae: 21.7604 - val_loss: 28.6386 - val_mae: 28.6386
#
# Epoch 00028: val_loss did not improve from 20.37339
# Epoch 29/250
# 78/78 [==============================] - 57s 739ms/step - loss: 21.5504 - mae: 21.5504 - val_loss: 23.9730 - val_mae: 23.9730
#
# Epoch 00029: val_loss did not improve from 20.37339
# Epoch 30/250
# 78/78 [==============================] - 58s 749ms/step - loss: 21.3013 - mae: 21.3013 - val_loss: 22.1075 - val_mae: 22.1075
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00691056102514267.
#
# Epoch 00030: val_loss did not improve from 20.37339
# Epoch 31/250
# 78/78 [==============================] - 58s 750ms/step - loss: 20.0791 - mae: 20.0791 - val_loss: 18.9508 - val_mae: 18.9508
#
# Epoch 00031: val_loss improved from 20.37339 to 18.95081, saving model to bone_age_weights.best.hdf5
# Epoch 32/250
# 78/78 [==============================] - 53s 685ms/step - loss: 20.7769 - mae: 20.7769 - val_loss: 20.9429 - val_mae: 20.9429
#
# Epoch 00032: val_loss did not improve from 18.95081
# Epoch 33/250
# 78/78 [==============================] - 58s 744ms/step - loss: 20.2066 - mae: 20.2066 - val_loss: 18.4401 - val_mae: 18.4401
#
# Epoch 00033: val_loss improved from 18.95081 to 18.44008, saving model to bone_age_weights.best.hdf5
# Epoch 34/250
# 78/78 [==============================] - 53s 676ms/step - loss: 19.7591 - mae: 19.7591 - val_loss: 23.2077 - val_mae: 23.2077
#
# Epoch 00034: val_loss did not improve from 18.44008
# Epoch 35/250
# 78/78 [==============================] - 58s 738ms/step - loss: 20.0258 - mae: 20.0258 - val_loss: 23.4756 - val_mae: 23.4756
#
# Epoch 00035: val_loss did not improve from 18.44008
# Epoch 36/250
# 78/78 [==============================] - 58s 746ms/step - loss: 18.8255 - mae: 18.8255 - val_loss: 17.9963 - val_mae: 17.9963
#
# Epoch 00036: val_loss improved from 18.44008 to 17.99632, saving model to bone_age_weights.best.hdf5
# Epoch 37/250
# 78/78 [==============================] - 56s 714ms/step - loss: 18.7381 - mae: 18.7381 - val_loss: 19.8222 - val_mae: 19.8222
#
# Epoch 00037: val_loss did not improve from 17.99632
# Epoch 38/250
# 78/78 [==============================] - 59s 750ms/step - loss: 19.0180 - mae: 19.0180 - val_loss: 18.0311 - val_mae: 18.0311
#
# Epoch 00038: val_loss did not improve from 17.99632
# Epoch 39/250
# 78/78 [==============================] - 48s 611ms/step - loss: 19.6920 - mae: 19.6920 - val_loss: 17.3792 - val_mae: 17.3792
#
# Epoch 00039: val_loss improved from 17.99632 to 17.37918, saving model to bone_age_weights.best.hdf5
# Epoch 40/250
# 78/78 [==============================] - 49s 634ms/step - loss: 18.2399 - mae: 18.2399 - val_loss: 17.1962 - val_mae: 17.1962
#
# Epoch 00040: val_loss improved from 17.37918 to 17.19621, saving model to bone_age_weights.best.hdf5
# Epoch 41/250
# 78/78 [==============================] - 49s 635ms/step - loss: 18.3212 - mae: 18.3212 - val_loss: 16.2349 - val_mae: 16.2349
#
# Epoch 00041: val_loss improved from 17.19621 to 16.23488, saving model to bone_age_weights.best.hdf5
# Epoch 42/250
# 78/78 [==============================] - 51s 649ms/step - loss: 17.4731 - mae: 17.4731 - val_loss: 21.7767 - val_mae: 21.7767
#
# Epoch 00042: val_loss did not improve from 16.23488
# Epoch 43/250
# 78/78 [==============================] - 55s 707ms/step - loss: 17.3324 - mae: 17.3324 - val_loss: 17.1761 - val_mae: 17.1761
#
# Epoch 00043: val_loss did not improve from 16.23488
# Epoch 44/250
# 78/78 [==============================] - 56s 717ms/step - loss: 17.0732 - mae: 17.0732 - val_loss: 18.6416 - val_mae: 18.6416
#
# Epoch 00044: val_loss did not improve from 16.23488
# Epoch 45/250
# 78/78 [==============================] - 56s 717ms/step - loss: 17.1159 - mae: 17.1159 - val_loss: 32.4567 - val_mae: 32.4567
#
# Epoch 00045: val_loss did not improve from 16.23488
# Epoch 46/250
# 78/78 [==============================] - 56s 724ms/step - loss: 16.7464 - mae: 16.7464 - val_loss: 21.0942 - val_mae: 21.0942
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.005528448894619942.
#
# Epoch 00046: val_loss did not improve from 16.23488
# Epoch 47/250
# 78/78 [==============================] - 56s 723ms/step - loss: 15.8936 - mae: 15.8936 - val_loss: 36.8137 - val_mae: 36.8137
#
# Epoch 00047: val_loss did not improve from 16.23488
# Epoch 48/250
# 78/78 [==============================] - 57s 736ms/step - loss: 16.2388 - mae: 16.2388 - val_loss: 14.0074 - val_mae: 14.0074
#
# Epoch 00048: val_loss improved from 16.23488 to 14.00741, saving model to bone_age_weights.best.hdf5
# Epoch 49/250
# 78/78 [==============================] - 53s 681ms/step - loss: 14.1602 - mae: 14.1602 - val_loss: 13.3456 - val_mae: 13.3456
#
# Epoch 00049: val_loss improved from 14.00741 to 13.34561, saving model to bone_age_weights.best.hdf5
# Epoch 50/250
# 78/78 [==============================] - 53s 678ms/step - loss: 14.3091 - mae: 14.3091 - val_loss: 12.5958 - val_mae: 12.5958
#
# Epoch 00050: val_loss improved from 13.34561 to 12.59577, saving model to bone_age_weights.best.hdf5
# Epoch 51/250
# 78/78 [==============================] - 53s 681ms/step - loss: 14.1461 - mae: 14.1461 - val_loss: 15.2321 - val_mae: 15.2321
#
# Epoch 00051: val_loss did not improve from 12.59577
# Epoch 52/250
# 78/78 [==============================] - 52s 668ms/step - loss: 13.5035 - mae: 13.5035 - val_loss: 12.3144 - val_mae: 12.3144
#
# Epoch 00052: val_loss improved from 12.59577 to 12.31435, saving model to bone_age_weights.best.hdf5
# Epoch 53/250
# 78/78 [==============================] - 52s 670ms/step - loss: 14.1909 - mae: 14.1909 - val_loss: 21.3627 - val_mae: 21.3627
#
# Epoch 00053: val_loss did not improve from 12.31435
# Epoch 54/250
# 78/78 [==============================] - 57s 727ms/step - loss: 13.2404 - mae: 13.2404 - val_loss: 11.6028 - val_mae: 11.6028
#
# Epoch 00054: val_loss improved from 12.31435 to 11.60278, saving model to bone_age_weights.best.hdf5
# Epoch 55/250
# 78/78 [==============================] - 53s 679ms/step - loss: 11.9691 - mae: 11.9691 - val_loss: 18.5595 - val_mae: 18.5595
#
# Epoch 00055: val_loss did not improve from 11.60278
# Epoch 56/250
# 78/78 [==============================] - 56s 721ms/step - loss: 11.8921 - mae: 11.8921 - val_loss: 12.9185 - val_mae: 12.9185
#
# Epoch 00056: val_loss did not improve from 11.60278
# Epoch 57/250
# 78/78 [==============================] - 56s 718ms/step - loss: 11.9130 - mae: 11.9130 - val_loss: 15.6092 - val_mae: 15.6092
#
# Epoch 00057: val_loss did not improve from 11.60278
# Epoch 58/250
# 78/78 [==============================] - 57s 729ms/step - loss: 11.4475 - mae: 11.4475 - val_loss: 15.0695 - val_mae: 15.0695
#
# Epoch 00058: val_loss did not improve from 11.60278
# Epoch 59/250
# 78/78 [==============================] - 54s 701ms/step - loss: 11.4672 - mae: 11.4672 - val_loss: 12.4775 - val_mae: 12.4775
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.004422759264707566.
#
# Epoch 00059: val_loss did not improve from 11.60278
# Epoch 60/250
# 78/78 [==============================] - 54s 698ms/step - loss: 10.7452 - mae: 10.7452 - val_loss: 16.7265 - val_mae: 16.7265
#
# Epoch 00060: val_loss did not improve from 11.60278
# Epoch 61/250
# 78/78 [==============================] - 55s 700ms/step - loss: 10.6277 - mae: 10.6277 - val_loss: 9.4113 - val_mae: 9.4113
#
# Epoch 00061: val_loss improved from 11.60278 to 9.41129, saving model to bone_age_weights.best.hdf5
# Epoch 62/250
# 78/78 [==============================] - 50s 647ms/step - loss: 10.1431 - mae: 10.1431 - val_loss: 9.1308 - val_mae: 9.1308
#
# Epoch 00062: val_loss improved from 9.41129 to 9.13084, saving model to bone_age_weights.best.hdf5
# Epoch 63/250
# 78/78 [==============================] - 52s 668ms/step - loss: 10.0056 - mae: 10.0056 - val_loss: 10.3067 - val_mae: 10.3067
#
# Epoch 00063: val_loss did not improve from 9.13084
# Epoch 64/250
# 78/78 [==============================] - 55s 707ms/step - loss: 9.8995 - mae: 9.8995 - val_loss: 9.6556 - val_mae: 9.6556
#
# Epoch 00064: val_loss did not improve from 9.13084
# Epoch 65/250
# 78/78 [==============================] - 56s 728ms/step - loss: 9.9958 - mae: 9.9958 - val_loss: 9.6400 - val_mae: 9.6400
#
# Epoch 00065: val_loss did not improve from 9.13084
# Epoch 66/250
# 78/78 [==============================] - 57s 729ms/step - loss: 9.9144 - mae: 9.9144 - val_loss: 9.7137 - val_mae: 9.7137
#
# Epoch 00066: val_loss did not improve from 9.13084
# Epoch 67/250
# 78/78 [==============================] - 56s 722ms/step - loss: 9.5244 - mae: 9.5244 - val_loss: 9.7351 - val_mae: 9.7351
#
# Epoch 00067: val_loss did not improve from 9.13084
# Epoch 68/250
# 78/78 [==============================] - 56s 723ms/step - loss: 9.8197 - mae: 9.8197 - val_loss: 9.4946 - val_mae: 9.4946
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.0035382073372602465.
#
# Epoch 00068: val_loss did not improve from 9.13084
# Epoch 69/250
# 78/78 [==============================] - 55s 714ms/step - loss: 9.6465 - mae: 9.6465 - val_loss: 9.5567 - val_mae: 9.5567
#
# Epoch 00069: val_loss did not improve from 9.13084
# Epoch 70/250
# 78/78 [==============================] - 56s 718ms/step - loss: 9.5016 - mae: 9.5016 - val_loss: 10.6685 - val_mae: 10.6685
#
# Epoch 00070: val_loss did not improve from 9.13084
# Epoch 71/250
# 78/78 [==============================] - 57s 729ms/step - loss: 9.0230 - mae: 9.0230 - val_loss: 9.4872 - val_mae: 9.4872
#
# Epoch 00071: val_loss did not improve from 9.13084
# Epoch 72/250
# 78/78 [==============================] - 57s 728ms/step - loss: 9.1681 - mae: 9.1681 - val_loss: 8.4904 - val_mae: 8.4904
#
# Epoch 00072: val_loss improved from 9.13084 to 8.49045, saving model to bone_age_weights.best.hdf5
# Epoch 73/250
# 78/78 [==============================] - 53s 679ms/step - loss: 8.8458 - mae: 8.8458 - val_loss: 11.1484 - val_mae: 11.1484
#
# Epoch 00073: val_loss did not improve from 8.49045
# Epoch 74/250
# 78/78 [==============================] - 56s 725ms/step - loss: 8.9973 - mae: 8.9973 - val_loss: 8.9642 - val_mae: 8.9642
#
# Epoch 00074: val_loss did not improve from 8.49045
# Epoch 75/250
# 78/78 [==============================] - 58s 746ms/step - loss: 9.0983 - mae: 9.0983 - val_loss: 9.7430 - val_mae: 9.7430
#
# Epoch 00075: val_loss did not improve from 8.49045
# Epoch 76/250
# 78/78 [==============================] - 58s 744ms/step - loss: 9.2557 - mae: 9.2557 - val_loss: 8.9229 - val_mae: 8.9229
#
# Epoch 00076: val_loss did not improve from 8.49045
# Epoch 77/250
# 78/78 [==============================] - 57s 731ms/step - loss: 8.9043 - mae: 8.9043 - val_loss: 9.0606 - val_mae: 9.0606
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.0028305659070611.
#
# Epoch 00077: val_loss did not improve from 8.49045
# Epoch 78/250
# 78/78 [==============================] - 54s 693ms/step - loss: 8.8535 - mae: 8.8535 - val_loss: 9.2198 - val_mae: 9.2198
#
# Epoch 00078: val_loss did not improve from 8.49045
# Epoch 79/250
# 78/78 [==============================] - 54s 693ms/step - loss: 8.6896 - mae: 8.6896 - val_loss: 8.6133 - val_mae: 8.6133
#
# Epoch 00079: val_loss did not improve from 8.49045
# Epoch 80/250
# 78/78 [==============================] - 54s 703ms/step - loss: 8.6232 - mae: 8.6232 - val_loss: 9.3170 - val_mae: 9.3170
#
# Epoch 00080: val_loss did not improve from 8.49045
# Epoch 81/250
# 78/78 [==============================] - 55s 715ms/step - loss: 8.6423 - mae: 8.6423 - val_loss: 8.2527 - val_mae: 8.2527
#
# Epoch 00081: val_loss improved from 8.49045 to 8.25271, saving model to bone_age_weights.best.hdf5
# Epoch 82/250
# 78/78 [==============================] - 50s 641ms/step - loss: 8.4126 - mae: 8.4126 - val_loss: 8.5571 - val_mae: 8.5571
#
# Epoch 00082: val_loss did not improve from 8.25271
# Epoch 83/250
# 78/78 [==============================] - 55s 715ms/step - loss: 8.3857 - mae: 8.3857 - val_loss: 9.2766 - val_mae: 9.2766
#
# Epoch 00083: val_loss did not improve from 8.25271
# Epoch 84/250
# 78/78 [==============================] - 55s 708ms/step - loss: 8.4791 - mae: 8.4791 - val_loss: 8.0536 - val_mae: 8.0536
#
# Epoch 00084: val_loss improved from 8.25271 to 8.05359, saving model to bone_age_weights.best.hdf5
# Epoch 85/250
# 78/78 [==============================] - 51s 651ms/step - loss: 8.2739 - mae: 8.2739 - val_loss: 8.1060 - val_mae: 8.1060
#
# Epoch 00085: val_loss did not improve from 8.05359
# Epoch 86/250
# 78/78 [==============================] - 55s 711ms/step - loss: 8.4180 - mae: 8.4180 - val_loss: 8.4291 - val_mae: 8.4291
#
# Epoch 00086: val_loss did not improve from 8.05359
# Epoch 87/250
# 78/78 [==============================] - 56s 716ms/step - loss: 8.4691 - mae: 8.4691 - val_loss: 8.9860 - val_mae: 8.9860
#
# Epoch 00087: val_loss did not improve from 8.05359
# Epoch 88/250
# 78/78 [==============================] - 55s 714ms/step - loss: 8.1952 - mae: 8.1952 - val_loss: 9.3711 - val_mae: 9.3711
#
# Epoch 00088: val_loss did not improve from 8.05359
# Epoch 89/250
# 78/78 [==============================] - 57s 728ms/step - loss: 8.4063 - mae: 8.4063 - val_loss: 8.5969 - val_mae: 8.5969
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.00226445272564888.
#
# Epoch 00089: val_loss did not improve from 8.05359
# Epoch 90/250
# 78/78 [==============================] - 57s 725ms/step - loss: 8.3167 - mae: 8.3167 - val_loss: 9.1877 - val_mae: 9.1877
#
# Epoch 00090: val_loss did not improve from 8.05359
# Epoch 91/250
# 78/78 [==============================] - 57s 729ms/step - loss: 8.1985 - mae: 8.1985 - val_loss: 8.2025 - val_mae: 8.2025
#
# Epoch 00091: val_loss did not improve from 8.05359
# Epoch 92/250
# 78/78 [==============================] - 57s 732ms/step - loss: 8.3804 - mae: 8.3804 - val_loss: 8.1974 - val_mae: 8.1974
#
# Epoch 00092: val_loss did not improve from 8.05359
# Epoch 93/250
# 78/78 [==============================] - 58s 744ms/step - loss: 8.2816 - mae: 8.2816 - val_loss: 8.0119 - val_mae: 8.0119
#
# Epoch 00093: val_loss improved from 8.05359 to 8.01193, saving model to bone_age_weights.best.hdf5
# Epoch 94/250
# 78/78 [==============================] - 56s 721ms/step - loss: 8.1072 - mae: 8.1072 - val_loss: 8.0895 - val_mae: 8.0895
#
# Epoch 00094: val_loss did not improve from 8.01193
# Epoch 95/250
# 78/78 [==============================] - 51s 645ms/step - loss: 8.2374 - mae: 8.2374 - val_loss: 8.5684 - val_mae: 8.5684
#
# Epoch 00095: val_loss did not improve from 8.01193
# Epoch 96/250
# 78/78 [==============================] - 55s 713ms/step - loss: 8.3051 - mae: 8.3051 - val_loss: 8.4390 - val_mae: 8.4390
#
# Epoch 00096: val_loss did not improve from 8.01193
# Epoch 97/250
# 78/78 [==============================] - 55s 707ms/step - loss: 8.1069 - mae: 8.1069 - val_loss: 8.6667 - val_mae: 8.6667
#
# Epoch 00097: val_loss did not improve from 8.01193
# Epoch 98/250
# 78/78 [==============================] - 55s 706ms/step - loss: 8.0854 - mae: 8.0854 - val_loss: 8.8247 - val_mae: 8.8247
#
# Epoch 00098: ReduceLROnPlateau reducing learning rate to 0.001811562106013298.
#
# Epoch 00098: val_loss did not improve from 8.01193
# Epoch 99/250
# 78/78 [==============================] - 55s 705ms/step - loss: 7.9091 - mae: 7.9091 - val_loss: 8.2198 - val_mae: 8.2198
#
# Epoch 00099: val_loss did not improve from 8.01193
# Epoch 100/250
# 78/78 [==============================] - 55s 710ms/step - loss: 7.8830 - mae: 7.8830 - val_loss: 8.8727 - val_mae: 8.8727
#
# Epoch 00100: val_loss did not improve from 8.01193
# Epoch 101/250
# 78/78 [==============================] - 55s 705ms/step - loss: 7.7774 - mae: 7.7774 - val_loss: 8.0808 - val_mae: 8.0808
#
# Epoch 00101: val_loss did not improve from 8.01193
# Epoch 102/250
# 78/78 [==============================] - 56s 717ms/step - loss: 7.9248 - mae: 7.9248 - val_loss: 8.9165 - val_mae: 8.9165
#
# Epoch 00102: val_loss did not improve from 8.01193
# Epoch 103/250
# 78/78 [==============================] - 56s 718ms/step - loss: 7.9108 - mae: 7.9108 - val_loss: 7.9204 - val_mae: 7.9204
#
# Epoch 00103: val_loss improved from 8.01193 to 7.92042, saving model to bone_age_weights.best.hdf5
# Epoch 104/250
# 78/78 [==============================] - 48s 621ms/step - loss: 8.0797 - mae: 8.0797 - val_loss: 7.9649 - val_mae: 7.9649
#
# Epoch 00104: val_loss did not improve from 7.92042
# Epoch 105/250
# 78/78 [==============================] - 56s 722ms/step - loss: 7.9845 - mae: 7.9845 - val_loss: 8.6873 - val_mae: 8.6873
#
# Epoch 00105: val_loss did not improve from 7.92042
# Epoch 106/250
# 78/78 [==============================] - 56s 724ms/step - loss: 7.9525 - mae: 7.9525 - val_loss: 8.1826 - val_mae: 8.1826
#
# Epoch 00106: val_loss did not improve from 7.92042
# Epoch 107/250
# 78/78 [==============================] - 56s 724ms/step - loss: 7.7826 - mae: 7.7826 - val_loss: 8.2190 - val_mae: 8.2190
#
# Epoch 00107: val_loss did not improve from 7.92042
# Epoch 108/250
# 78/78 [==============================] - 56s 726ms/step - loss: 7.7248 - mae: 7.7248 - val_loss: 8.3600 - val_mae: 8.3600
#
# Epoch 00108: ReduceLROnPlateau reducing learning rate to 0.0014492496848106384.
#
# Epoch 00108: val_loss did not improve from 7.92042
# Epoch 109/250
# 78/78 [==============================] - 57s 730ms/step - loss: 7.7435 - mae: 7.7435 - val_loss: 8.0829 - val_mae: 8.0829
#
# Epoch 00109: val_loss did not improve from 7.92042
# Epoch 110/250
# 78/78 [==============================] - 57s 739ms/step - loss: 7.7080 - mae: 7.7080 - val_loss: 7.9174 - val_mae: 7.9174
#
# Epoch 00110: val_loss improved from 7.92042 to 7.91738, saving model to bone_age_weights.best.hdf5
# Epoch 111/250
# 78/78 [==============================] - 56s 724ms/step - loss: 7.7152 - mae: 7.7152 - val_loss: 9.3764 - val_mae: 9.3764
#
# Epoch 00111: val_loss did not improve from 7.91738
# Epoch 112/250
# 78/78 [==============================] - 57s 737ms/step - loss: 7.7332 - mae: 7.7332 - val_loss: 7.8887 - val_mae: 7.8887
#
# Epoch 00112: val_loss improved from 7.91738 to 7.88870, saving model to bone_age_weights.best.hdf5
# Epoch 113/250
# 78/78 [==============================] - 56s 722ms/step - loss: 7.8287 - mae: 7.8287 - val_loss: 7.9249 - val_mae: 7.9249
#
# Epoch 00113: val_loss did not improve from 7.88870
# Epoch 114/250
# 78/78 [==============================] - 53s 686ms/step - loss: 7.6444 - mae: 7.6444 - val_loss: 8.5576 - val_mae: 8.5576
#
# Epoch 00114: val_loss did not improve from 7.88870
# Epoch 115/250
# 78/78 [==============================] - 49s 627ms/step - loss: 7.6715 - mae: 7.6715 - val_loss: 7.7326 - val_mae: 7.7326
#
# Epoch 00115: val_loss improved from 7.88870 to 7.73264, saving model to bone_age_weights.best.hdf5
# Epoch 116/250
# 78/78 [==============================] - 49s 629ms/step - loss: 7.5943 - mae: 7.5943 - val_loss: 7.8925 - val_mae: 7.8925
#
# Epoch 00116: val_loss did not improve from 7.73264
# Epoch 117/250
# 78/78 [==============================] - 54s 701ms/step - loss: 7.5287 - mae: 7.5287 - val_loss: 7.8411 - val_mae: 7.8411
#
# Epoch 00117: val_loss did not improve from 7.73264
# Epoch 118/250
# 78/78 [==============================] - 54s 696ms/step - loss: 7.5755 - mae: 7.5755 - val_loss: 8.0424 - val_mae: 8.0424
#
# Epoch 00118: val_loss did not improve from 7.73264
# Epoch 119/250
# 78/78 [==============================] - 55s 705ms/step - loss: 7.6611 - mae: 7.6611 - val_loss: 7.9497 - val_mae: 7.9497
#
# Epoch 00119: val_loss did not improve from 7.73264
# Epoch 120/250
# 78/78 [==============================] - 55s 708ms/step - loss: 7.6727 - mae: 7.6727 - val_loss: 8.1870 - val_mae: 8.1870
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 0.0011593997478485107.
#
# Epoch 00120: val_loss did not improve from 7.73264
# Epoch 121/250
# 78/78 [==============================] - 56s 716ms/step - loss: 7.5464 - mae: 7.5464 - val_loss: 7.6170 - val_mae: 7.6170
#
# Epoch 00121: val_loss improved from 7.73264 to 7.61697, saving model to bone_age_weights.best.hdf5
# Epoch 122/250
# 78/78 [==============================] - 50s 644ms/step - loss: 7.4521 - mae: 7.4521 - val_loss: 8.3096 - val_mae: 8.3096
#
# Epoch 00122: val_loss did not improve from 7.61697
# Epoch 123/250
# 78/78 [==============================] - 56s 729ms/step - loss: 7.5323 - mae: 7.5323 - val_loss: 7.9353 - val_mae: 7.9353
#
# Epoch 00123: val_loss did not improve from 7.61697
# Epoch 124/250
# 78/78 [==============================] - 57s 731ms/step - loss: 7.5357 - mae: 7.5357 - val_loss: 8.0378 - val_mae: 8.0378
#
# Epoch 00124: val_loss did not improve from 7.61697
# Epoch 125/250
# 78/78 [==============================] - 57s 738ms/step - loss: 7.5190 - mae: 7.5190 - val_loss: 7.7498 - val_mae: 7.7498
#
# Epoch 00125: val_loss did not improve from 7.61697
# Epoch 126/250
# 78/78 [==============================] - 58s 746ms/step - loss: 7.5475 - mae: 7.5475 - val_loss: 8.0758 - val_mae: 8.0758
#
# Epoch 00126: val_loss did not improve from 7.61697
# Epoch 127/250
# 78/78 [==============================] - 58s 745ms/step - loss: 7.4829 - mae: 7.4829 - val_loss: 8.0995 - val_mae: 8.0995
#
# Epoch 00127: val_loss did not improve from 7.61697
# Epoch 128/250
# 78/78 [==============================] - 58s 745ms/step - loss: 7.4880 - mae: 7.4880 - val_loss: 7.7517 - val_mae: 7.7517
#
# Epoch 00128: val_loss did not improve from 7.61697
# Epoch 129/250
# 78/78 [==============================] - 58s 746ms/step - loss: 7.5100 - mae: 7.5100 - val_loss: 7.9116 - val_mae: 7.9116
#
# Epoch 00129: ReduceLROnPlateau reducing learning rate to 0.0009275197982788086.
#
# Epoch 00129: val_loss did not improve from 7.61697
# Epoch 130/250
# 78/78 [==============================] - 58s 744ms/step - loss: 7.3577 - mae: 7.3577 - val_loss: 7.7149 - val_mae: 7.7149
#
# Epoch 00130: val_loss did not improve from 7.61697
# Epoch 131/250
# 78/78 [==============================] - 58s 747ms/step - loss: 7.4411 - mae: 7.4411 - val_loss: 7.5234 - val_mae: 7.5234
#
# Epoch 00131: val_loss improved from 7.61697 to 7.52335, saving model to bone_age_weights.best.hdf5
# Epoch 132/250
# 78/78 [==============================] - 57s 730ms/step - loss: 7.3836 - mae: 7.3836 - val_loss: 8.9006 - val_mae: 8.9006
#
# Epoch 00132: val_loss did not improve from 7.52335
# Epoch 133/250
# 78/78 [==============================] - 56s 728ms/step - loss: 7.4255 - mae: 7.4255 - val_loss: 7.5139 - val_mae: 7.5139
#
# Epoch 00133: val_loss improved from 7.52335 to 7.51388, saving model to bone_age_weights.best.hdf5
# Epoch 134/250
# 78/78 [==============================] - 58s 744ms/step - loss: 7.3207 - mae: 7.3207 - val_loss: 7.6850 - val_mae: 7.6850
#
# Epoch 00134: val_loss did not improve from 7.51388
# Epoch 135/250
# 78/78 [==============================] - 42s 534ms/step - loss: 7.3774 - mae: 7.3774 - val_loss: 8.2349 - val_mae: 8.2349
#
# Epoch 00135: val_loss did not improve from 7.51388
# Epoch 136/250
# 78/78 [==============================] - 54s 693ms/step - loss: 7.3727 - mae: 7.3727 - val_loss: 8.2200 - val_mae: 8.2200
#
# Epoch 00136: val_loss did not improve from 7.51388
# Epoch 137/250
# 78/78 [==============================] - 54s 695ms/step - loss: 7.2613 - mae: 7.2613 - val_loss: 7.6148 - val_mae: 7.6148
#
# Epoch 00137: val_loss did not improve from 7.51388
# Epoch 138/250
# 78/78 [==============================] - 55s 708ms/step - loss: 7.2436 - mae: 7.2436 - val_loss: 7.5349 - val_mae: 7.5349
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 0.0007420158479362727.
#
# Epoch 00138: val_loss did not improve from 7.51388
# Epoch 139/250
# 78/78 [==============================] - 55s 707ms/step - loss: 7.2905 - mae: 7.2905 - val_loss: 7.4626 - val_mae: 7.4626
#
# Epoch 00139: val_loss improved from 7.51388 to 7.46256, saving model to bone_age_weights.best.hdf5
# Epoch 140/250
# 78/78 [==============================] - 47s 603ms/step - loss: 7.2389 - mae: 7.2389 - val_loss: 7.4366 - val_mae: 7.4366
#
# Epoch 00140: val_loss improved from 7.46256 to 7.43656, saving model to bone_age_weights.best.hdf5
# Epoch 141/250
# 78/78 [==============================] - 49s 633ms/step - loss: 7.2877 - mae: 7.2877 - val_loss: 7.4080 - val_mae: 7.4080
#
# Epoch 00141: val_loss improved from 7.43656 to 7.40803, saving model to bone_age_weights.best.hdf5
# Epoch 142/250
# 78/78 [==============================] - 50s 640ms/step - loss: 7.2166 - mae: 7.2166 - val_loss: 7.4342 - val_mae: 7.4342
#
# Epoch 00142: val_loss did not improve from 7.40803
# Epoch 143/250
# 78/78 [==============================] - 57s 731ms/step - loss: 7.2201 - mae: 7.2201 - val_loss: 7.5483 - val_mae: 7.5483
#
# Epoch 00143: val_loss did not improve from 7.40803
# Epoch 144/250
# 78/78 [==============================] - 57s 733ms/step - loss: 7.2343 - mae: 7.2343 - val_loss: 8.1198 - val_mae: 8.1198
#
# Epoch 00144: val_loss did not improve from 7.40803
# Epoch 145/250
# 78/78 [==============================] - 58s 743ms/step - loss: 7.2677 - mae: 7.2677 - val_loss: 7.7043 - val_mae: 7.7043
#
# Epoch 00145: val_loss did not improve from 7.40803
# Epoch 146/250
# 78/78 [==============================] - 57s 737ms/step - loss: 7.2029 - mae: 7.2029 - val_loss: 7.6131 - val_mae: 7.6131
#
# Epoch 00146: val_loss did not improve from 7.40803
# Epoch 147/250
# 78/78 [==============================] - 57s 734ms/step - loss: 7.2615 - mae: 7.2615 - val_loss: 8.1627 - val_mae: 8.1627
#
# Epoch 00147: ReduceLROnPlateau reducing learning rate to 0.0005936126690357924.
#
# Epoch 00147: val_loss did not improve from 7.40803
# Epoch 148/250
# 78/78 [==============================] - 59s 761ms/step - loss: 7.1228 - mae: 7.1228 - val_loss: 7.5091 - val_mae: 7.5091
#
# Epoch 00148: val_loss did not improve from 7.40803
# Epoch 149/250
# 78/78 [==============================] - 57s 732ms/step - loss: 7.1000 - mae: 7.1000 - val_loss: 7.6616 - val_mae: 7.6616
#
# Epoch 00149: val_loss did not improve from 7.40803
# Epoch 150/250
# 78/78 [==============================] - 58s 739ms/step - loss: 7.0643 - mae: 7.0643 - val_loss: 7.6899 - val_mae: 7.6899
#
# Epoch 00150: val_loss did not improve from 7.40803
# Epoch 151/250
# 78/78 [==============================] - 58s 740ms/step - loss: 7.0251 - mae: 7.0251 - val_loss: 7.4062 - val_mae: 7.4062
#
# Epoch 00151: val_loss improved from 7.40803 to 7.40625, saving model to bone_age_weights.best.hdf5
# Epoch 152/250
# 78/78 [==============================] - 53s 680ms/step - loss: 7.0825 - mae: 7.0825 - val_loss: 7.4103 - val_mae: 7.4103
#
# Epoch 00152: val_loss did not improve from 7.40625
# Epoch 153/250
# 78/78 [==============================] - 60s 767ms/step - loss: 7.1120 - mae: 7.1120 - val_loss: 7.3674 - val_mae: 7.3674
#
# Epoch 00153: val_loss improved from 7.40625 to 7.36741, saving model to bone_age_weights.best.hdf5
# Epoch 154/250
# 78/78 [==============================] - 53s 676ms/step - loss: 7.1161 - mae: 7.1161 - val_loss: 7.7452 - val_mae: 7.7452
#
# Epoch 00154: val_loss did not improve from 7.36741
# Epoch 155/250
# 78/78 [==============================] - 57s 736ms/step - loss: 7.1479 - mae: 7.1479 - val_loss: 7.5221 - val_mae: 7.5221
#
# Epoch 00155: val_loss did not improve from 7.36741
# Epoch 156/250
# 78/78 [==============================] - 60s 767ms/step - loss: 7.0743 - mae: 7.0743 - val_loss: 7.4472 - val_mae: 7.4472
#
# Epoch 00156: val_loss did not improve from 7.36741
# Epoch 157/250
# 78/78 [==============================] - 60s 774ms/step - loss: 7.1548 - mae: 7.1548 - val_loss: 7.4817 - val_mae: 7.4817
#
# Epoch 00157: val_loss did not improve from 7.36741
# Epoch 158/250
# 78/78 [==============================] - 57s 740ms/step - loss: 7.0663 - mae: 7.0663 - val_loss: 7.3306 - val_mae: 7.3306
#
# Epoch 00158: val_loss improved from 7.36741 to 7.33056, saving model to bone_age_weights.best.hdf5
# Epoch 159/250
# 78/78 [==============================] - 55s 707ms/step - loss: 7.0888 - mae: 7.0888 - val_loss: 7.3094 - val_mae: 7.3094
#
# Epoch 00159: val_loss improved from 7.33056 to 7.30941, saving model to bone_age_weights.best.hdf5
# Epoch 160/250
# 78/78 [==============================] - 58s 742ms/step - loss: 6.9612 - mae: 6.9612 - val_loss: 7.4517 - val_mae: 7.4517
#
# Epoch 00160: val_loss did not improve from 7.30941
# Epoch 161/250
# 78/78 [==============================] - 48s 617ms/step - loss: 7.0812 - mae: 7.0812 - val_loss: 7.6153 - val_mae: 7.6153
#
# Epoch 00161: val_loss did not improve from 7.30941
# Epoch 162/250
# 78/78 [==============================] - 51s 659ms/step - loss: 7.1115 - mae: 7.1115 - val_loss: 7.4687 - val_mae: 7.4687
#
# Epoch 00162: val_loss did not improve from 7.30941
# Epoch 163/250
# 78/78 [==============================] - 54s 701ms/step - loss: 6.9710 - mae: 6.9710 - val_loss: 7.5267 - val_mae: 7.5267
#
# Epoch 00163: val_loss did not improve from 7.30941
# Epoch 164/250
# 78/78 [==============================] - 54s 700ms/step - loss: 7.1740 - mae: 7.1740 - val_loss: 7.4760 - val_mae: 7.4760
#
# Epoch 00164: ReduceLROnPlateau reducing learning rate to 0.0004748901352286339.
#
# Epoch 00164: val_loss did not improve from 7.30941
# Epoch 165/250
# 78/78 [==============================] - 55s 706ms/step - loss: 7.0814 - mae: 7.0814 - val_loss: 7.2857 - val_mae: 7.2857
#
# Epoch 00165: val_loss improved from 7.30941 to 7.28574, saving model to bone_age_weights.best.hdf5
# Epoch 166/250
# 78/78 [==============================] - 51s 658ms/step - loss: 7.0162 - mae: 7.0162 - val_loss: 7.5478 - val_mae: 7.5478
#
# Epoch 00166: val_loss did not improve from 7.28574
# Epoch 167/250
# 78/78 [==============================] - 57s 731ms/step - loss: 7.0383 - mae: 7.0383 - val_loss: 7.2930 - val_mae: 7.2930
#
# Epoch 00167: val_loss did not improve from 7.28574
# Epoch 168/250
# 78/78 [==============================] - 55s 714ms/step - loss: 7.0836 - mae: 7.0836 - val_loss: 7.3658 - val_mae: 7.3658
#
# Epoch 00168: val_loss did not improve from 7.28574
# Epoch 169/250
# 78/78 [==============================] - 56s 723ms/step - loss: 7.0768 - mae: 7.0768 - val_loss: 7.3462 - val_mae: 7.3462
#
# Epoch 00169: val_loss did not improve from 7.28574
# Epoch 170/250
# 78/78 [==============================] - 57s 735ms/step - loss: 7.0263 - mae: 7.0263 - val_loss: 7.4118 - val_mae: 7.4118
#
# Epoch 00170: val_loss did not improve from 7.28574
# Epoch 171/250
# 78/78 [==============================] - 56s 715ms/step - loss: 7.0160 - mae: 7.0160 - val_loss: 7.4401 - val_mae: 7.4401
#
# Epoch 00171: val_loss did not improve from 7.28574
# Epoch 172/250
# 78/78 [==============================] - 56s 723ms/step - loss: 6.8955 - mae: 6.8955 - val_loss: 7.2913 - val_mae: 7.2913
#
# Epoch 00172: val_loss did not improve from 7.28574
# Epoch 173/250
# 78/78 [==============================] - 57s 730ms/step - loss: 7.0670 - mae: 7.0670 - val_loss: 7.2782 - val_mae: 7.2782
#
# Epoch 00173: val_loss improved from 7.28574 to 7.27822, saving model to bone_age_weights.best.hdf5
# Epoch 174/250
# 78/78 [==============================] - 52s 664ms/step - loss: 7.0110 - mae: 7.0110 - val_loss: 7.3295 - val_mae: 7.3295
#
# Epoch 00174: val_loss did not improve from 7.27822
# Epoch 175/250
# 78/78 [==============================] - 56s 727ms/step - loss: 7.0128 - mae: 7.0128 - val_loss: 7.6485 - val_mae: 7.6485
#
# Epoch 00175: val_loss did not improve from 7.27822
# Epoch 176/250
# 78/78 [==============================] - 57s 731ms/step - loss: 6.8362 - mae: 6.8362 - val_loss: 7.3315 - val_mae: 7.3315
#
# Epoch 00176: val_loss did not improve from 7.27822
# Epoch 177/250
# 78/78 [==============================] - 58s 738ms/step - loss: 6.9691 - mae: 6.9691 - val_loss: 7.4520 - val_mae: 7.4520
#
# Epoch 00177: val_loss did not improve from 7.27822
# Epoch 178/250
# 78/78 [==============================] - 58s 745ms/step - loss: 6.8829 - mae: 6.8829 - val_loss: 7.3928 - val_mae: 7.3928
#
# Epoch 00178: ReduceLROnPlateau reducing learning rate to 0.00037991211283952.
#
# Epoch 00178: val_loss did not improve from 7.27822
# Epoch 179/250
# 78/78 [==============================] - 57s 736ms/step - loss: 7.0239 - mae: 7.0239 - val_loss: 7.4666 - val_mae: 7.4666
#
# Epoch 00179: val_loss did not improve from 7.27822
# Epoch 180/250
# 78/78 [==============================] - 54s 701ms/step - loss: 6.9183 - mae: 6.9183 - val_loss: 7.3922 - val_mae: 7.3922
#
# Epoch 00180: val_loss did not improve from 7.27822
# Epoch 181/250
# 78/78 [==============================] - 54s 698ms/step - loss: 6.8665 - mae: 6.8665 - val_loss: 7.3241 - val_mae: 7.3241
#
# Epoch 00181: val_loss did not improve from 7.27822
# Epoch 182/250
# 78/78 [==============================] - 54s 701ms/step - loss: 7.0277 - mae: 7.0277 - val_loss: 7.3316 - val_mae: 7.3316
#
# Epoch 00182: val_loss did not improve from 7.27822
# Epoch 183/250
# 78/78 [==============================] - 56s 722ms/step - loss: 6.9093 - mae: 6.9093 - val_loss: 7.3210 - val_mae: 7.3210
#
# Epoch 00183: val_loss did not improve from 7.27822
# Epoch 184/250
# 78/78 [==============================] - 56s 720ms/step - loss: 6.8335 - mae: 6.8335 - val_loss: 7.4729 - val_mae: 7.4729
#
# Epoch 00184: val_loss did not improve from 7.27822
# Epoch 185/250
# 78/78 [==============================] - 55s 714ms/step - loss: 6.9458 - mae: 6.9458 - val_loss: 7.3105 - val_mae: 7.3105
#
# Epoch 00185: val_loss did not improve from 7.27822
# Epoch 186/250
# 78/78 [==============================] - 55s 715ms/step - loss: 6.8193 - mae: 6.8193 - val_loss: 7.2863 - val_mae: 7.2863
#
# Epoch 00186: val_loss did not improve from 7.27822
# Epoch 187/250
# 78/78 [==============================] - 56s 721ms/step - loss: 6.8940 - mae: 6.8940 - val_loss: 7.4795 - val_mae: 7.4795
#
# Epoch 00187: ReduceLROnPlateau reducing learning rate to 0.0003039296949282289.
#
# Epoch 00187: val_loss did not improve from 7.27822
# Epoch 188/250
# 78/78 [==============================] - 56s 718ms/step - loss: 6.9077 - mae: 6.9077 - val_loss: 7.4552 - val_mae: 7.4552
#
# Epoch 00188: val_loss did not improve from 7.27822
# Epoch 189/250
# 78/78 [==============================] - 56s 723ms/step - loss: 6.9685 - mae: 6.9685 - val_loss: 7.2939 - val_mae: 7.2939
#
# Epoch 00189: val_loss did not improve from 7.27822
# Epoch 190/250
# 78/78 [==============================] - 56s 719ms/step - loss: 6.8572 - mae: 6.8572 - val_loss: 7.4114 - val_mae: 7.4114
#
# Epoch 00190: val_loss did not improve from 7.27822
# Epoch 191/250
# 78/78 [==============================] - 56s 719ms/step - loss: 6.8469 - mae: 6.8469 - val_loss: 7.5184 - val_mae: 7.5184
#
# Epoch 00191: val_loss did not improve from 7.27822
# Epoch 192/250
# 78/78 [==============================] - 57s 729ms/step - loss: 6.9036 - mae: 6.9036 - val_loss: 7.6083 - val_mae: 7.6083
#
# Epoch 00192: val_loss did not improve from 7.27822
# Epoch 193/250
# 78/78 [==============================] - 57s 731ms/step - loss: 6.8414 - mae: 6.8414 - val_loss: 7.2374 - val_mae: 7.2374
#
# Epoch 00193: val_loss improved from 7.27822 to 7.23739, saving model to bone_age_weights.best.hdf5
# Epoch 194/250
# 78/78 [==============================] - 55s 703ms/step - loss: 6.8797 - mae: 6.8797 - val_loss: 7.4229 - val_mae: 7.4229
#
# Epoch 00194: val_loss did not improve from 7.23739
# Epoch 195/250
# 78/78 [==============================] - 56s 715ms/step - loss: 6.9456 - mae: 6.9456 - val_loss: 7.2764 - val_mae: 7.2764
#
# Epoch 00195: val_loss did not improve from 7.23739
# Epoch 196/250
# 78/78 [==============================] - 57s 742ms/step - loss: 6.8885 - mae: 6.8885 - val_loss: 7.2864 - val_mae: 7.2864
#
# Epoch 00196: val_loss did not improve from 7.23739
# Epoch 197/250
# 78/78 [==============================] - 54s 694ms/step - loss: 6.8642 - mae: 6.8642 - val_loss: 7.3249 - val_mae: 7.3249
#
# Epoch 00197: val_loss did not improve from 7.23739
# Epoch 198/250
# 78/78 [==============================] - 53s 675ms/step - loss: 6.9296 - mae: 6.9296 - val_loss: 7.2482 - val_mae: 7.2482
#
# Epoch 00198: ReduceLROnPlateau reducing learning rate to 0.00024314376059919596.
#
# Epoch 00198: val_loss did not improve from 7.23739
# Epoch 199/250
# 78/78 [==============================] - 55s 707ms/step - loss: 6.7995 - mae: 6.7995 - val_loss: 7.2751 - val_mae: 7.2751
#
# Epoch 00199: val_loss did not improve from 7.23739
# Epoch 200/250
# 78/78 [==============================] - 55s 705ms/step - loss: 6.8712 - mae: 6.8712 - val_loss: 7.2088 - val_mae: 7.2088
#
# Epoch 00200: val_loss improved from 7.23739 to 7.20880, saving model to bone_age_weights.best.hdf5
# Epoch 201/250
# 78/78 [==============================] - 50s 639ms/step - loss: 6.8253 - mae: 6.8253 - val_loss: 7.3100 - val_mae: 7.3100
#
# Epoch 00201: val_loss did not improve from 7.20880
# Epoch 202/250
# 78/78 [==============================] - 55s 708ms/step - loss: 6.9000 - mae: 6.9000 - val_loss: 7.2153 - val_mae: 7.2153
#
# Epoch 00202: val_loss did not improve from 7.20880
# Epoch 203/250
# 78/78 [==============================] - 55s 713ms/step - loss: 6.8330 - mae: 6.8330 - val_loss: 7.3271 - val_mae: 7.3271
#
# Epoch 00203: val_loss did not improve from 7.20880
# Epoch 204/250
# 78/78 [==============================] - 56s 718ms/step - loss: 6.8818 - mae: 6.8818 - val_loss: 7.2308 - val_mae: 7.2308
#
# Epoch 00204: val_loss did not improve from 7.20880
# Epoch 205/250
# 78/78 [==============================] - 56s 718ms/step - loss: 6.7870 - mae: 6.7870 - val_loss: 7.2939 - val_mae: 7.2939
#
# Epoch 00205: val_loss did not improve from 7.20880
# Epoch 206/250
# 78/78 [==============================] - 56s 719ms/step - loss: 6.8730 - mae: 6.8730 - val_loss: 7.4351 - val_mae: 7.4351
#
# Epoch 00206: val_loss did not improve from 7.20880
# Epoch 207/250
# 78/78 [==============================] - 56s 717ms/step - loss: 6.8506 - mae: 6.8506 - val_loss: 7.2579 - val_mae: 7.2579
#
# Epoch 00207: ReduceLROnPlateau reducing learning rate to 0.0001945150084793568.
#
# Epoch 00207: val_loss did not improve from 7.20880
# Epoch 208/250
# 78/78 [==============================] - 56s 721ms/step - loss: 6.8450 - mae: 6.8450 - val_loss: 7.2485 - val_mae: 7.2485
#
# Epoch 00208: val_loss did not improve from 7.20880
# Epoch 209/250
# 78/78 [==============================] - 57s 732ms/step - loss: 6.7741 - mae: 6.7741 - val_loss: 7.4037 - val_mae: 7.4037
#
# Epoch 00209: val_loss did not improve from 7.20880
# Epoch 210/250
# 78/78 [==============================] - 56s 727ms/step - loss: 6.8536 - mae: 6.8536 - val_loss: 7.3078 - val_mae: 7.3078
#
# Epoch 00210: val_loss did not improve from 7.20880
# Epoch 211/250
# 78/78 [==============================] - 56s 724ms/step - loss: 6.9739 - mae: 6.9739 - val_loss: 7.4576 - val_mae: 7.4576
#
# Epoch 00211: val_loss did not improve from 7.20880
# Epoch 212/250
# 78/78 [==============================] - 57s 731ms/step - loss: 6.9265 - mae: 6.9265 - val_loss: 7.2582 - val_mae: 7.2582
#
# Epoch 00212: val_loss did not improve from 7.20880
# Epoch 213/250
# 78/78 [==============================] - 59s 755ms/step - loss: 6.9018 - mae: 6.9018 - val_loss: 7.2556 - val_mae: 7.2556
#
# Epoch 00213: val_loss did not improve from 7.20880
# Epoch 214/250
# 78/78 [==============================] - 59s 758ms/step - loss: 6.8370 - mae: 6.8370 - val_loss: 7.3155 - val_mae: 7.3155
#
# Epoch 00214: val_loss did not improve from 7.20880
# Epoch 215/250
# 78/78 [==============================] - 58s 746ms/step - loss: 6.7717 - mae: 6.7717 - val_loss: 7.3847 - val_mae: 7.3847
#
# Epoch 00215: val_loss did not improve from 7.20880
# Epoch 216/250
# 78/78 [==============================] - 58s 746ms/step - loss: 6.8557 - mae: 6.8557 - val_loss: 7.3205 - val_mae: 7.3205
#
# Epoch 00216: ReduceLROnPlateau reducing learning rate to 0.00015561201144009829.
#
# Epoch 00216: val_loss did not improve from 7.20880
# Epoch 217/250
# 78/78 [==============================] - 52s 665ms/step - loss: 6.8069 - mae: 6.8069 - val_loss: 7.2211 - val_mae: 7.2211
#
# Epoch 00217: val_loss did not improve from 7.20880
# Epoch 218/250
# 78/78 [==============================] - 53s 689ms/step - loss: 6.7266 - mae: 6.7266 - val_loss: 7.2748 - val_mae: 7.2748
#
# Epoch 00218: val_loss did not improve from 7.20880
# Epoch 219/250
# 78/78 [==============================] - 55s 705ms/step - loss: 6.8858 - mae: 6.8858 - val_loss: 7.3233 - val_mae: 7.3233
#
# Epoch 00219: val_loss did not improve from 7.20880
# Epoch 220/250
# 78/78 [==============================] - 55s 707ms/step - loss: 6.7741 - mae: 6.7741 - val_loss: 7.3265 - val_mae: 7.3265
#
# Epoch 00220: val_loss did not improve from 7.20880
